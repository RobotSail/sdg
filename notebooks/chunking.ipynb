# %% [markdown]
# - have a variable qna.yaml = ""
# - pull the document from the github path/file system path in the qna.yaml
# - chunk this document using docling v2
# - once you have these chunks, use the SDG functions to do the icl_mapping
# - have an input that goes into generate_data
# - Have synthetically generated data

# %% [markdown]
# ## How Chunking works in SDG

# %%
from instructlab.sdg.utils.taxonomy import read_taxonomy
from pathlib import Path


yaml_path = Path('./qna.yaml')


data = read_taxonomy(
  taxonomy=yaml_path,
  taxonomy_base='origin/main',
  yaml_rules=None,
  document_output_dir=None
)
# Out:
# Error retrieving documents: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://github.com/rhai-code/instructlab_knowledge None
#   stderr: 'fatal: destination path 'None' already exists and is not an empty directory.
# '
# ---------------------------------------------------------------------------
# GitCommandError                           Traceback (most recent call last)
# File ~/Programming/labrador/sdg/src/instructlab/sdg/utils/taxonomy.py:266, in _read_taxonomy_file(file_path, yamllint_config, document_output_dir)
#     265 if documents:
# --> 266     document_contents, doc_filepaths = _get_documents(
#     267         source=documents, document_output_dir=document_output_dir
#     268     )
#     269     logger.debug("Content from git repo fetched")
#
# File ~/Programming/labrador/sdg/src/instructlab/sdg/utils/taxonomy.py:236, in _get_documents(source, skip_checkout, document_output_dir)
#     235 logger.error("Error retrieving documents: %s", str(e))
# --> 236 raise e
#
# File ~/Programming/labrador/sdg/src/instructlab/sdg/utils/taxonomy.py:139, in _get_documents(source, skip_checkout, document_output_dir)
#     138 try:  # pylint: disable=too-many-nested-blocks
# --> 139     repo = git.Repo.clone_from(repo_url, document_output_dir)
#     141     if not skip_checkout and commit_hash:
#
# File ~/Programming/labrador/sdg/venv/lib/python3.11/site-packages/git/repo/base.py:1525, in Repo.clone_from(cls, url, to_path, progress, env, multi_options, allow_unsafe_protocols, allow_unsafe_options, **kwargs)
#    1524     git.update_environment(**env)
# -> 1525 return cls._clone(
#    1526     git,
#    1527     url,
#    1528     to_path,
#    1529     GitCmdObjectDB,
#    1530     progress,
#    1531     multi_options,
#    1532     allow_unsafe_protocols=allow_unsafe_protocols,
#    1533     allow_unsafe_options=allow_unsafe_options,
#    1534     **kwargs,
#    1535 )
#
# File ~/Programming/labrador/sdg/venv/lib/python3.11/site-packages/git/repo/base.py:1396, in Repo._clone(cls, git, url, path, odb_default_type, progress, multi_options, allow_unsafe_protocols, allow_unsafe_options, **kwargs)
#    1395     _logger.debug("Cmd(%s)'s unused stdout: %s", cmdline, stdout)
# -> 1396     finalize_process(proc, stderr=stderr)
#    1398 # Our git command could have a different working dir than our actual
#    1399 # environment, hence we prepend its working dir if required.
#
# File ~/Programming/labrador/sdg/venv/lib/python3.11/site-packages/git/util.py:504, in finalize_process(proc, **kwargs)
#     503 # TODO: No close proc-streams??
# --> 504 proc.wait(**kwargs)
#
# File ~/Programming/labrador/sdg/venv/lib/python3.11/site-packages/git/cmd.py:834, in Git.AutoInterrupt.wait(self, stderr)
#     833     _logger.debug("AutoInterrupt wait stderr: %r" % (errstr,))
# --> 834     raise GitCommandError(remove_password_if_present(self.args), status, errstr)
#     835 return status
#
# GitCommandError: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://github.com/rhai-code/instructlab_knowledge None
#   stderr: 'fatal: destination path 'None' already exists and is not an empty directory.
# '
#
# The above exception was the direct cause of the following exception:
#
# TaxonomyReadingException                  Traceback (most recent call last)
# Cell In[6], line 8
#       2 from pathlib import Path
#       5 yaml_path = Path('./qna.yaml')
# ----> 8 data = read_taxonomy(
#       9   taxonomy=yaml_path,
#      10   taxonomy_base='origin/main',
#      11   yaml_rules=None,
#      12   document_output_dir=None
#      13 )
#      14 data[0]
#
# File ~/Programming/labrador/sdg/src/instructlab/sdg/utils/taxonomy.py:325, in read_taxonomy(taxonomy, taxonomy_base, yaml_rules, document_output_dir)
#     323 is_file = os.path.isfile(taxonomy)
#     324 if is_file:  # taxonomy is file
# --> 325     seed_instruction_data, warnings, errors = _read_taxonomy_file(
#     326         taxonomy, yamllint_config, document_output_dir
#     327     )
#     328     if warnings:
#     329         logger.warning(
#     330             f"{warnings} warnings (see above) due to taxonomy file not (fully) usable."
#     331         )
#
# File ~/Programming/labrador/sdg/src/instructlab/sdg/utils/taxonomy.py:302, in _read_taxonomy_file(file_path, yamllint_config, document_output_dir)
#     290             seed_instruction_data.append(
#     291                 {
#     292                     "instruction": question,
#    (...)
#     299                 }
#     300             )
#     301 except Exception as e:
# --> 302     raise TaxonomyReadingException(f"Exception {e} raised in {file_path}") from e
#     304 return seed_instruction_data, 0, 0
#
# TaxonomyReadingException: Exception Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://github.com/rhai-code/instructlab_knowledge None
#   stderr: 'fatal: destination path 'None' already exists and is not an empty directory.
# ' raised in qna.yaml

# %%
data[0]
# Out:
# {'questions_and_answers': [{'question': 'What is InstructLab?\n',
#    'answer': 'InstructLab is an open source AI project\nthat faciliates contributions to Large Language Models (LLMs).\n'},
#   {'question': 'Can anyone contribute to InstructLab?\n',
#    'answer': 'Yes, the community welcomes everyone\ninterested in generative AI.\n'},
#   {'question': 'What is the mission of InstructLab?\n',
#    'answer': 'We are on a mission to let anyone\nshape generative AI by enabling contributed\nupdates to existing LLMs in an accessible way.\nOur community welcomes all those who\nwould like to help us enable everyone\nto shape the future of generative AI.\n'}],
#  'context': 'InstructLab is a model-agnostic open source AI project that facilitates\ncontributions to Large Language Models (LLMs).\nWe are on a mission to let anyone shape generative\nAI by enabling contributed updates to existing\nLLMs in an accessible way. Our community welcomes all those who\nwould like to help us enable everyone to shape\nthe future of generative AI.\n',
#  'taxonomy_path': '/->Users->osilkin->Programming->labrador->sdg->notebooks',
#  'documents': ['# Welcome to the 🐶 InstructLab Project\n\n![Banner](https://github.com/instructlab/.github/blob/main/assets/instructlab-banner.png)\nInstructLab is a model-agnostic open source AI project that facilitates contributions to Large Language Models (LLMs).\n\nWe are on a mission to let anyone shape generative AI by enabling contributed updates to existing LLMs in an accessible way.\n\n**Our community welcomes all those who would like to help us enable ***everyone*** to shape the future of generative AI.**\n\n## Why InstructLab\n\nThere are many projects rapidly embracing and extending permissively licensed AI models, but they are faced with three main challenges:\n\n* Contribution to LLMs is not possible directly. They show up as forks, which forces consumers to choose a “best-fit” model that isn’t easily extensible. Also, the forks are expensive for model creators to maintain.\n* The ability to contribute ideas is limited by a lack of AI/ML expertise. One has to learn how to fork, train, and refine models to see their idea move forward. This is a high barrier to entry.\n* There is no direct community governance or best practice around review, curation, and distribution of forked models.\n\n**InstructLab is here to solve these problems.**\n\nThe project enables community contributors to add additional "skills" or "knowledge" to a particular model.\n\nInstructLab\'s model-agnostic technology gives model upstreams with sufficient infrastructure resources the ability to create regular builds of their open source licensed models not by rebuilding and retraining the entire model but by composing new skills into it.\n\nTake a look at "lab-enhanced" models on the [InstructLab Hugging Face page](https://huggingface.co/instructlab).\n\n## Get Started with InstructLab\n\n* Check out the [Community README](https://github.com/instructlab/community/blob/main/README.md) to get started with using and contributing to the project.\n* You may wish to read through the [project\'s FAQ](https://github.com/instructlab/community/blob/main/FAQ.md) to get more familiar with all aspects of InstructLab.\n* If you want to jump right in, head to the [`ilab` documentation](https://github.com/instructlab/instructlab/blob/main/README.md) to get InstructLab set up and running.\n* Learn more about the [skills and knowledge](https://github.com/instructlab/taxonomy/blob/main/README.md) you can add to models.\n* You can find all the ways to collaborate with project maintainers and your fellow users of InstructLab beyond GitHub by visiting our [project collaboration](https://github.com/instructlab/community/blob/main/Collaboration.md) page.\n* When you are ready to make a contribution to the project, please take a few minutes to look over our [contribution guidelines](https://github.com/instructlab/community/blob/main/CONTRIBUTING.md) to ensure your contribution is aligned with the project policies.\n\n## Community Meetings\n\nFor folks getting started with all things InstructLab, it may be easiest for you to join one of our community meetings and speak with project maintainers and other InstructLab collaborators live. You can find details on all of our community meetings, including our open office hours each Thursday, in our detailed [Project Meetings documentation](https://github.com/instructlab/community/blob/main/Collaboration.md#project-meetings).\n\nEveryone is welcome and encouraged to attend if they will find value in joining. Please note that some meetings are recorded and the recordings [published in our project YouTube channel](https://www.youtube.com/@InstructLab/playlists). The meeting host will advise all attendees if the meeting is being recorded. If you prefer to join camera off or dial in via phone so as to not be actively recorded and/or you prefer not to be on camera during meetings, that is absolutely no problem.\n\n## Code of Conduct\n\nParticipation in all aspects of the InstructLab community (including but not limited to community ...
#  'filepaths': [PosixPath('/Users/osilkin/Programming/labrador/sdg/notebooks/None/instructlab.md')],
#  'domain': 'instructlab',
#  'document_outline': 'Details on the InstructLab community project.\n'}

# %% [markdown]
# Inspecting the contents of the processed data, we see that there are a few keys:
#
# ```
# dict_keys([
#   'questions_and_answers',
#   'context',
#   'taxonomy_path',
#   'documents',
#   'filepaths',
#   'domain',
#   'document_outline',
# ])
# ```

# %%
sample = data[0]
sep_length = 400

# context from the qna
print(sample['context'])
print('-' * sep_length)

# path in the taxonomy
print(sample['taxonomy_path'])
print('-' * sep_length)
# documents list
print(sample['documents'])

# filepaths
print('-' * sep_length)
print(sample['filepaths'])


# domain
print('-' * sep_length)
print(sample['domain'])

# document_outline
print('-' * sep_length)
print(sample['document_outline'])
# Out:
# InstructLab is a model-agnostic open source AI project that facilitates
# contributions to Large Language Models (LLMs).
# We are on a mission to let anyone shape generative
# AI by enabling contributed updates to existing
# LLMs in an accessible way. Our community welcomes all those who
# would like to help us enable everyone to shape
# the future of generative AI.
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# /->Users->osilkin->Programming->labrador->sdg->notebooks
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ['# Welcome to the 🐶 InstructLab Project\n\n![Banner](https://github.com/instructlab/.github/blob/main/assets/instructlab-banner.png)\nInstructLab is a model-agnostic open source AI project that facilitates contributions to Large Language Models (LLMs).\n\nWe are on a mission to let anyone shape generative AI by enabling contributed updates to existing LLMs in an accessible way.\n\n**Our community welcomes all those who would like to help us enable ***everyone*** to shape the future of generative AI.**\n\n## Why InstructLab\n\nThere are many projects rapidly embracing and extending permissively licensed AI models, but they are faced with three main challenges:\n\n* Contribution to LLMs is not possible directly. They show up as forks, which forces consumers to choose a “best-fit” model that isn’t easily extensible. Also, the forks are expensive for model creators to maintain.\n* The ability to contribute ideas is limited by a lack of AI/ML expertise. One has to learn how to fork, train, and refine models to see their idea move forward. This is a high barrier to entry.\n* There is no direct community governance or best practice around review, curation, and distribution of forked models.\n\n**InstructLab is here to solve these problems.**\n\nThe project enables community contributors to add additional "skills" or "knowledge" to a particular model.\n\nInstructLab\'s model-agnostic technology gives model upstreams with sufficient infrastructure resources the ability to create regular builds of their open source licensed models not by rebuilding and retraining the entire model but by composing new skills into it.\n\nTake a look at "lab-enhanced" models on the [InstructLab Hugging Face page](https://huggingface.co/instructlab).\n\n## Get Started with InstructLab\n\n* Check out the [Community README](https://github.com/instructlab/community/blob/main/README.md) to get started with using and contributing to the project.\n* You may wish to read through the [project\'s FAQ](https://github.com/instructlab/community/blob/main/FAQ.md) to get more familiar with all aspects of InstructLab.\n* If you want to jump right in, head to the [`ilab` documentation](https://github.com/instructlab/instructlab/blob/main/README.md) to get InstructLab set up and running.\n* Learn more about the [skills and knowledge](https://github.com/instructlab/taxonomy/blob/main/README.md) you can add to models.\n* You can find all the ways to collaborate with project maintainers and your fellow users of InstructLab beyond GitHub by visiting our [project collaboration](https://github.com/instructlab/community/blob/main/Collaboration.md) page.\n* When you are ready to make a contribution to the project, please take a few minutes to look over our [contribution guidelines](https://github.com/instructlab/community/blob/main/CONTRIBUTING.md) to ensure your contribution is aligned with the project policies.\n\n## Community Meetings\n\nFor folks getting started with all things InstructLab, it may be easiest for you to join one of our community meetings and speak with project maintainers and other InstructLab collaborators live. You can find details on all of our community meetings, including our open office hours each Thursday, in our detailed [Project Meetings documentation](https://github.com/instructlab/community/blob/main/Collaboration.md#project-meetings).\n\nEveryone is welcome and encouraged to attend if they will find value in joining. Please note that some meetings are recorded and the recordings [published in our project YouTube channel](https://www.youtube.com/@InstructLab/playlists). The meeting host will advise all attendees if the meeting is being recorded. If you prefer to join camera off or dial in via phone so as to not be actively recorded and/or you prefer not to be on camera during meetings, that is absolutely no problem.\n\n## Code of Conduct\n\nParticipation in all aspects of the InstructLab community (including but not limited to community meetings, mai ...
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [PosixPath('/Users/osilkin/Programming/labrador/sdg/notebooks/None/instructlab.md')]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# instructlab
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Details on the InstructLab community project.

# %% [markdown]
# It looks like a lot of these fields are taken directly from the `qna.yaml` file. However; one that seems to be unique is the `documents` field, let's take a closer look:

# %%
len(sample['documents'])
# Out:
# 1

# %% [markdown]
# It looks like it's a list of documents, in our case we only provided a single document source, so it makes sense that there's only one document in the list. Let's print it out to see what it contains

# %%
from IPython.display import display, Markdown


# Display it as rendered markdown
display(Markdown(sample['documents'][0]))
# Out:
# # Welcome to the 🐶 InstructLab Project
#
# ![Banner](https://github.com/instructlab/.github/blob/main/assets/instructlab-banner.png)
# InstructLab is a model-agnostic open source AI project that facilitates contributions to Large Language Models (LLMs).
#
# We are on a mission to let anyone shape generative AI by enabling contributed updates to existing LLMs in an accessible way.
#
# **Our community welcomes all those who would like to help us enable ***everyone*** to shape the future of generative AI.**
#
# ## Why InstructLab
#
# There are many projects rapidly embracing and extending permissively licensed AI models, but they are faced with three main challenges:
#
# * Contribution to LLMs is not possible directly. They show up as forks, which forces consumers to choose a “best-fit” model that isn’t easily extensible. Also, the forks are expensive for model creators to maintain.
# * The ability to contribute ideas is limited by a lack of AI/ML expertise. One has to learn how to fork, train, and refine models to see their idea move forward. This is a high barrier to entry.
# * There is no direct community governance or best practice around review, curation, and distribution of forked models.
#
# **InstructLab is here to solve these problems.**
#
# The project enables community contributors to add additional "skills" or "knowledge" to a particular model.
#
# InstructLab's model-agnostic technology gives model upstreams with sufficient infrastructure resources the ability to create regular builds of their open source licensed models not by rebuilding and retraining the entire model but by composing new skills into it.
#
# Take a look at "lab-enhanced" models on the [InstructLab Hugging Face page](https://huggingface.co/instructlab).
#
# ## Get Started with InstructLab
#
# * Check out the [Community README](https://github.com/instructlab/community/blob/main/README.md) to get started with using and contributing to the project.
# * You may wish to read through the [project's FAQ](https://github.com/instructlab/community/blob/main/FAQ.md) to get more familiar with all aspects of InstructLab.
# * If you want to jump right in, head to the [`ilab` documentation](https://github.com/instructlab/instructlab/blob/main/README.md) to get InstructLab set up and running.
# * Learn more about the [skills and knowledge](https://github.com/instructlab/taxonomy/blob/main/README.md) you can add to models.
# * You can find all the ways to collaborate with project maintainers and your fellow users of InstructLab beyond GitHub by visiting our [project collaboration](https://github.com/instructlab/community/blob/main/Collaboration.md) page.
# * When you are ready to make a contribution to the project, please take a few minutes to look over our [contribution guidelines](https://github.com/instructlab/community/blob/main/CONTRIBUTING.md) to ensure your contribution is aligned with the project policies.
#
# ## Community Meetings
#
# For folks getting started with all things InstructLab, it may be easiest for you to join one of our community meetings and speak with project maintainers and other InstructLab collaborators live. You can find details on all of our community meetings, including our open office hours each Thursday, in our detailed [Project Meetings documentation](https://github.com/instructlab/community/blob/main/Collaboration.md#project-meetings).
#
# Everyone is welcome and encouraged to attend if they will find value in joining. Please note that some meetings are recorded and the recordings [published in our project YouTube channel](https://www.youtube.com/@InstructLab/playlists). The meeting host will advise all attendees if the meeting is being recorded. If you prefer to join camera off or dial in via phone so as to not be actively recorded and/or you prefer not to be on camera during meetings, that is absolutely no problem.
#
# ## Code of Conduct
#
# Participation in all aspects of the InstructLab community (including but not limited to community meetings, mailing lists, real-time chat, and the project GitHub repos) is governed by our [Code of Conduct](https://github.com/instructlab/community/blob/main/CODE_OF_CONDUCT.md).
#
# ## Quick Links
#
# ### Governance
#
# See the [project governance document](https://github.com/instructlab/community/blob/main/GOVERNANCE.md) for an overview of how InstructLab project operates.
#
# ### Security
#
# Security policies and practices, including reporting vulnerabilities, can be found in our [security document](https://github.com/instructlab/community/blob/main/SECURITY.md).
#
# ### Read the Paper
#
# InstructLab 🐶 uses a novel synthetic data-based alignment tuning method for Large Language Models (LLMs.) The "lab" in InstructLab 🥼 stands for [**L**arge-Scale **A**lignment for Chat**B**ots](https://arxiv.org/abs/2403.01081) [1].
#
# [1] Shivchander Sudalairaj*, Abhishek Bhandwaldar*, Aldo Pareja*, Kai Xu, David D. Cox, Akash Srivastava*. "LAB: Large-Scale Alignment for ChatBots", arXiv preprint arXiv: 2403.01081, 2024. (* denotes equal contributions)
#
# ## Acknowledgements
#
# The InstructLab project is sponsored by Red Hat.
#
# InstructLab was originally created by engineers from Red Hat and IBM Research.
#
# The infrastructure used to regularly train models based on new contributions from the community is donated and maintained by IBM.

# %% [markdown]
# Unsurprisingly, it contains the markdown content of the InstructLab README file.

# %% [markdown]
# Now let's create a separate `qna.yaml` file using an example cat shelter PDF.

# %%
from instructlab.sdg.utils.taxonomy import read_taxonomy
from pathlib import Path


yaml_path = Path('./cat-shelter-example/qna.yaml')


data = read_taxonomy(
  taxonomy=yaml_path,
  taxonomy_base='origin/main',
  yaml_rules=None,
  document_output_dir=None
)
# Out:
# WARNING: content stream objects stream 697 0 (content, offset 3285): parse error while reading object
# WARNING: content stream objects stream 698 0 (content, offset 3): unexpected dictionary close token

# %% [markdown]
# Learnings:
#
# - A `qna.yaml` **must** have 5 context entries.
# - Each context entry must be comprised of a unique set of questions and answers. Duplicates will throw an error

# %%
data
# Out:
# [{'questions_and_answers': [{'question': 'What is a feral cat shelter?\n',
#     'answer': 'A feral cat shelter is a structure designed to provide protection from inclement weather for feral cat colonies.\n'},
#    {'question': 'What is the mission of Alley Cat Allies?\n',
#     'answer': 'Alley Cat Allies is a nonprofit organization dedicated to promoting the humane treatment of feral and free-roaming cats.\n'},
#    {'question': 'What types of shelters are recommended for feral cat colonies?\n',
#     'answer': 'Dog igloos can be used in less harsh climates.\nFor extremely harsh, cold, and wet climates, insulation is advised.\n'}],
#   'context': 'Alley Cat Allies recommends that feral cat colonies have proper protection from inclement weather.\nFollowing are detailed instructions needed to build a feral cat shelter. These building plans are\nrecommended for use throughout the United States. For extremely harsh, cold, and wet climates,\ninsulation (as described) is advised. Other types of shelters, such as dog igloos, can be used in less\nharsh climates. Go to www.alleycat.org/BuildaShelter for additional shelter ideas.\n',
#   'taxonomy_path': '/->Users->osilkin->Programming->labrador->sdg->notebooks->cat-shelter-example',
#   'documents': ['www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017\nBUILD AN INEXPENSIVE CAT SHELTER\nThe following instructions are for building an\ninsulated cat shelter 2 ft. x 3 ft. x 18in. high.\nYou should be able to buy the materials at a local lumberyard.\nAn electric saw and screwdriver are highly recommended.\nCaution: If you are not experienced with an electric saw, ask a\nskilled person to cut the wood and paneling.\nMaterials Needed\n•\nOne 4-ft. x 1/2-in x 8-ft. sheet of exterior grade plywood\nor waferboard\n•\nOne 4-ft. x 8-ft. sheet interior paneling or thin plywood\nOne package roofing shingles or enough to cover\n8-sq. ft. roof\n•\nTwo 2-in. x 3-in. x 6-ft. untreated lumber\nLinoleum or other floor tiles (to cover 6-sq. ft. floor)\n•\nOne quart exterior house paint\nTwo medium hinges (“T” or gate hinges)\n•\nFifty 2-in. flat head wood screws or grippers\nFour to nine bricks for foundation\n•\nSmall roofing nails (approximately 15)\nFiberglass insulation (1 roll, or enough to cover 14-20 sq. ft.)\nTools Needed\n•\nHammer\nSaw\n•\nElectric screw\ndriver\n•\nAngle brace or\nT-square\n•\nStaple gun\nMeasuring tape\n•\nMarking pen\nThings to consider before starting your project\nThese will help you determine what you need to buy and\nhow much work will be involved, and also provide a few\nhelpful hints.\n•\nHow many cats do you need to house? This number\ndetemines how many shelters to build. Keep in mind that\nnot all cats are likely to use the shelter, or at least not all at\nthe same time. This shelter should probably house no more\nthan five to seven cats at once. You can adjust this plan\nto make a larger shelter, or build more than one shelter\nas needed.\nCaregiving\nInformation\nA\nlley Cat Allies recommends that feral cat colonies have proper protection from inclement weather.\nFollowing are detailed instructions needed to build a feral cat shelter. These building plans are\nrecommended for use throughout the United States. For extremely harsh, cold, and wet climates,\ninsulation (as described) is advised. Other types of shelters, such as dog igloos, can be used in less\nharsh climates. Go to www.alleycat.org/BuildaShelter for additional shelter ideas.\nCompleted shelter\nCaregiving Information\n317P\nFact Sheet:\nwww.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017\nBUILD AN INEXPENSIVE CAT SHELTER, page 2 of 4\n•\nBe sure to make the shelter small enough for transport in\nyour vehicle. The shelter size described here will fit in a\nstandard size car trunk with the trunk lid open.\n•\nIf you live in a climate that gets very cold, we recommend\nthat you use insulation as described in the plans.\n•\nUse only exterior paint to reduce weather exposure,\npreferably dark green or dark brown to match natural\nsurroundings.\n•\nFloor should have linoleum or tile square instead of\ncarpet to reduce the chance of flea infestation. Carpets and\ntowels retain moisture and should not be used.\nAssembly\n1.\nCut wood. For easy assembly, cut all wood first, then\nassemble the shelter. Some pieces may need adjustment\nafter cutting.\nCut plywood as shown at right. (This is only enough for\none shelter.)\nCut paneling as shown at right. One sheet of paneling\nis enough for two shelters.\nCut 2-in. x 3-in. x 6-ft. lumber into eight posts and\ntwo shelf braces as shown at right.\n•\nUse screws, not nails, for better durability.\nRoof should be hinged so bedding can be replaced, and\nfor easy access when retrieving kittens who may be in\nthe shelter.\n•\nRoof must be slanted to drain off water.\nA wind block should be placed inside the door of the shelter\nto improve warmth. You may also consider a canvas flap to\ngo over the door.\n•\nPlace wood chips or straw inside for warmth and comfort.\nBlankets, towels, and carpets retain moisture.\nPlywood Cutting Guidelines\nPaneling Cutting Guidelines\nLumber Cutting Guidelines\nFact Sheet:\nwww.alleycat.org • 7920 ...
#   'filepaths': [PosixPath('/Users/osilkin/Programming/labrador/sdg/notebooks/None/cat-shelter.pdf')],
#   'domain': 'cat-shelter',
#   'document_outline': 'Details on building a feral cat shelter.\n'},
#  {'questions_and_answers': [{'question': 'How many cats can a feral cat shelter house?\n',
#     'answer': 'A feral cat shelter should probably house no more\nthan five to seven cats at once.\n'},
#    {'question': 'What is the best way to determine how many shelters to build?\n',
#     'answer': 'The number of cats you need to house determines how many shelters to build.\n'},
#    {'question': 'What materials are needed to build a feral cat shelter?\n',
#     'answer': 'One 4-ft. x 1/2-in x 8-ft. sheet of exterior grade plywood\nor waferboard, one 4-ft. x 8-ft. sheet interior paneling or thin plywood,\none package roofing shingles or enough to cover 8-sq. ft. roof,\ntwo 2-in. x 3-in. x 6-ft. untreated lumber,\nLinoleum or other floor tiles (to cover 6-sq. ft. floor),\nOne quart exterior house paint, two medium hinges, fifty 2-in. flat head wood screws or grippers,\nFour to nine bricks for foundation, small roofing nails, fiberglass insulation.\n'}],
#   'context': 'Things to consider before starting your project:\nThese will help you determine what you need to buy and\nhow much work will be involved, and also provide a few\nhelpful hints.\n- How many cats do you need to house? This number\n  determines how many shelters to build. Keep in mind that\n  not all cats are likely to use the shelter, or at least not all at\n  the same time. This shelter should probably house no more\n  than five to seven cats at once. You can adjust this plan\n  to make a larger shelter, or build more than one shelter\n  as needed.\n',
#   'taxonomy_path': '/->Users->osilkin->Programming->labrador->sdg->notebooks->cat-shelter-example',
#   'documents': ['www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017\nBUILD AN INEXPENSIVE CAT SHELTER\nThe following instructions are for building an\ninsulated cat shelter 2 ft. x 3 ft. x 18in. high.\nYou should be able to buy the materials at a local lumberyard.\nAn electric saw and screwdriver are highly recommended.\nCaution: If you are not experienced with an electric saw, ask a\nskilled person to cut the wood and paneling.\nMaterials Needed\n•\nOne 4-ft. x 1/2-in x 8-ft. sheet of exterior grade plywood\nor waferboard\n•\nOne 4-ft. x 8-ft. sheet interior paneling or thin plywood\nOne package roofing shingles or enough to cover\n8-sq. ft. roof\n•\nTwo 2-in. x 3-in. x 6-ft. untreated lumber\nLinoleum or other floor tiles (to cover 6-sq. ft. floor)\n•\nOne quart exterior house paint\nTwo medium hinges (“T” or gate hinges)\n•\nFifty 2-in. flat head wood screws or grippers\nFour to nine bricks for foundation\n•\nSmall roofing nails (approximately 15)\nFiberglass insulation (1 roll, or enough to cover 14-20 sq. ft.)\nTools Needed\n•\nHammer\nSaw\n•\nElectric screw\ndriver\n•\nAngle brace or\nT-square\n•\nStaple gun\nMeasuring tape\n•\nMarking pen\nThings to consider before starting your project\nThese will help you determine what you need to buy and\nhow much work will be involved, and also provide a few\nhelpful hints.\n•\nHow many cats do you need to house? This number\ndetemines how many shelters to build. Keep in mind that\nnot all cats are likely to use the shelter, or at least not all at\nthe same time. This shelter should probably house no more\nthan five to seven cats at once. You can adjust this plan\nto make a larger shelter, or build more than one shelter\nas needed.\nCaregiving\nInformation\nA\nlley Cat Allies recommends that feral cat colonies have proper protection from inclement weather.\nFollowing are detailed instructions needed to build a feral cat shelter. These building plans are\nrecommended for use throughout the United States. For extremely harsh, cold, and wet climates,\ninsulation (as described) is advised. Other types of shelters, such as dog igloos, can be used in less\nharsh climates. Go to www.alleycat.org/BuildaShelter for additional shelter ideas.\nCompleted shelter\nCaregiving Information\n317P\nFact Sheet:\nwww.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017\nBUILD AN INEXPENSIVE CAT SHELTER, page 2 of 4\n•\nBe sure to make the shelter small enough for transport in\nyour vehicle. The shelter size described here will fit in a\nstandard size car trunk with the trunk lid open.\n•\nIf you live in a climate that gets very cold, we recommend\nthat you use insulation as described in the plans.\n•\nUse only exterior paint to reduce weather exposure,\npreferably dark green or dark brown to match natural\nsurroundings.\n•\nFloor should have linoleum or tile square instead of\ncarpet to reduce the chance of flea infestation. Carpets and\ntowels retain moisture and should not be used.\nAssembly\n1.\nCut wood. For easy assembly, cut all wood first, then\nassemble the shelter. Some pieces may need adjustment\nafter cutting.\nCut plywood as shown at right. (This is only enough for\none shelter.)\nCut paneling as shown at right. One sheet of paneling\nis enough for two shelters.\nCut 2-in. x 3-in. x 6-ft. lumber into eight posts and\ntwo shelf braces as shown at right.\n•\nUse screws, not nails, for better durability.\nRoof should be hinged so bedding can be replaced, and\nfor easy access when retrieving kittens who may be in\nthe shelter.\n•\nRoof must be slanted to drain off water.\nA wind block should be placed inside the door of the shelter\nto improve warmth. You may also consider a canvas flap to\ngo over the door.\n•\nPlace wood chips or straw inside for warmth and comfort.\nBlankets, towels, and carpets retain moisture.\nPlywood Cutting Guidelines\nPaneling Cutting Guidelines\nLumber Cutting Guidelines\nFact Sheet:\nwww.alleycat.org • 7920 ...
#   'filepaths': [PosixPath('/Users/osilkin/Programming/labrador/sdg/notebooks/None/cat-shelter.pdf')],
#   'domain': 'cat-shelter',
#   'document_outline': 'Details on building a feral cat shelter.\n'},
#  {'questions_and_answers': [{'question': 'How to assemble a feral cat shelter?\n',
#     'answer': 'Cut wood. For easy assembly, cut all wood first, then\nassemble the shelter. Some pieces may need adjustment\nafter cutting.\n'},
#    {'question': 'How to attach the walls to the base?\n',
#     'answer': 'Put side wall A in place on the left of the base and screw\nfront wall and left side wall together using one 17-in. corner\npost. Position side wall B on the right and attach to front wall\nusing other 17-in. corner post. Position back wall and attach to both side walls using two\n11-in. corner posts.\n'},
#    {'question': 'Where should side wall B be placed?\n',
#     'answer': 'Position side wall B on the right and attach to front wall\nusing other 17-in. corner post.\n'}],
#   'context': '1. Cut wood. For easy assembly, cut all wood first, then\nassemble the shelter. Some pieces may need adjustment\nafter cutting.\n2. Put side wall A in place on the left of the base and screw\nfront wall and left side wall together using one 17-in. corner\npost.\n3. Position side wall B on the right and attach to front wall\nusing other 17-in. corner post.\n4. Position back wall and attach to both side walls using two\n11-in. corner posts. Note: Corner posts should rest on\ntop of the base, as should the front, back, and side walls.\nAll posts should be inside of the front, back, and side walls.\n',
#   'taxonomy_path': '/->Users->osilkin->Programming->labrador->sdg->notebooks->cat-shelter-example',
#   'documents': ['www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017\nBUILD AN INEXPENSIVE CAT SHELTER\nThe following instructions are for building an\ninsulated cat shelter 2 ft. x 3 ft. x 18in. high.\nYou should be able to buy the materials at a local lumberyard.\nAn electric saw and screwdriver are highly recommended.\nCaution: If you are not experienced with an electric saw, ask a\nskilled person to cut the wood and paneling.\nMaterials Needed\n•\nOne 4-ft. x 1/2-in x 8-ft. sheet of exterior grade plywood\nor waferboard\n•\nOne 4-ft. x 8-ft. sheet interior paneling or thin plywood\nOne package roofing shingles or enough to cover\n8-sq. ft. roof\n•\nTwo 2-in. x 3-in. x 6-ft. untreated lumber\nLinoleum or other floor tiles (to cover 6-sq. ft. floor)\n•\nOne quart exterior house paint\nTwo medium hinges (“T” or gate hinges)\n•\nFifty 2-in. flat head wood screws or grippers\nFour to nine bricks for foundation\n•\nSmall roofing nails (approximately 15)\nFiberglass insulation (1 roll, or enough to cover 14-20 sq. ft.)\nTools Needed\n•\nHammer\nSaw\n•\nElectric screw\ndriver\n•\nAngle brace or\nT-square\n•\nStaple gun\nMeasuring tape\n•\nMarking pen\nThings to consider before starting your project\nThese will help you determine what you need to buy and\nhow much work will be involved, and also provide a few\nhelpful hints.\n•\nHow many cats do you need to house? This number\ndetemines how many shelters to build. Keep in mind that\nnot all cats are likely to use the shelter, or at least not all at\nthe same time. This shelter should probably house no more\nthan five to seven cats at once. You can adjust this plan\nto make a larger shelter, or build more than one shelter\nas needed.\nCaregiving\nInformation\nA\nlley Cat Allies recommends that feral cat colonies have proper protection from inclement weather.\nFollowing are detailed instructions needed to build a feral cat shelter. These building plans are\nrecommended for use throughout the United States. For extremely harsh, cold, and wet climates,\ninsulation (as described) is advised. Other types of shelters, such as dog igloos, can be used in less\nharsh climates. Go to www.alleycat.org/BuildaShelter for additional shelter ideas.\nCompleted shelter\nCaregiving Information\n317P\nFact Sheet:\nwww.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017\nBUILD AN INEXPENSIVE CAT SHELTER, page 2 of 4\n•\nBe sure to make the shelter small enough for transport in\nyour vehicle. The shelter size described here will fit in a\nstandard size car trunk with the trunk lid open.\n•\nIf you live in a climate that gets very cold, we recommend\nthat you use insulation as described in the plans.\n•\nUse only exterior paint to reduce weather exposure,\npreferably dark green or dark brown to match natural\nsurroundings.\n•\nFloor should have linoleum or tile square instead of\ncarpet to reduce the chance of flea infestation. Carpets and\ntowels retain moisture and should not be used.\nAssembly\n1.\nCut wood. For easy assembly, cut all wood first, then\nassemble the shelter. Some pieces may need adjustment\nafter cutting.\nCut plywood as shown at right. (This is only enough for\none shelter.)\nCut paneling as shown at right. One sheet of paneling\nis enough for two shelters.\nCut 2-in. x 3-in. x 6-ft. lumber into eight posts and\ntwo shelf braces as shown at right.\n•\nUse screws, not nails, for better durability.\nRoof should be hinged so bedding can be replaced, and\nfor easy access when retrieving kittens who may be in\nthe shelter.\n•\nRoof must be slanted to drain off water.\nA wind block should be placed inside the door of the shelter\nto improve warmth. You may also consider a canvas flap to\ngo over the door.\n•\nPlace wood chips or straw inside for warmth and comfort.\nBlankets, towels, and carpets retain moisture.\nPlywood Cutting Guidelines\nPaneling Cutting Guidelines\nLumber Cutting Guidelines\nFact Sheet:\nwww.alleycat.org • 7920 ...
#   'filepaths': [PosixPath('/Users/osilkin/Programming/labrador/sdg/notebooks/None/cat-shelter.pdf')],
#   'domain': 'cat-shelter',
#   'document_outline': 'Details on building a feral cat shelter.\n'},
#  {'questions_and_answers': [{'question': 'What is the best way to insulate a feral cat shelter?\n',
#     'answer': 'You can insulate the shelter with strong plastic to keep out wind, rain, and cold.\n'},
#    {'question': 'What is the best way to leave a small opening for the cats to enter?\n',
#     'answer': 'Leave a small opening for the cats to enter. A flap can be placed\nover the entrance for added protection.\n'},
#    {'question': 'What materials are needed to build a feral cat shelter?\n',
#     'answer': 'One 4-ft. x 1/2-in x 8-ft. sheet of exterior grade plywood\nor waferboard, one 4-ft. x 8-ft. sheet interior paneling or thin plywood,\none package roofing shingles or enough to cover 8-sq. ft. roof,\ntwo 2-in. x 3-in. x 6-ft. untreated lumber,\nLinoleum or other floor tiles (to cover 6-sq. ft. floor),\nOne quart exterior house paint, two medium hinges, fifty 2-in. flat head wood screws or grippers,\n'}],
#   'context': 'Note: You may also cover the interior underside of the roof\nwith fiberglass or plastic foam insulation, but be sure to cover\nit with plastic or wood. Foam needs to be covered to hold it in\nplace, and uncovered fiberglass will harm cats. You can insulate\nthe shelter with strong plastic to keep out wind, rain, and cold.\nLeave a small opening for the cats to enter. A flap can be placed\nover the entrance for added protection.\n',
#   'taxonomy_path': '/->Users->osilkin->Programming->labrador->sdg->notebooks->cat-shelter-example',
#   'documents': ['www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017\nBUILD AN INEXPENSIVE CAT SHELTER\nThe following instructions are for building an\ninsulated cat shelter 2 ft. x 3 ft. x 18in. high.\nYou should be able to buy the materials at a local lumberyard.\nAn electric saw and screwdriver are highly recommended.\nCaution: If you are not experienced with an electric saw, ask a\nskilled person to cut the wood and paneling.\nMaterials Needed\n•\nOne 4-ft. x 1/2-in x 8-ft. sheet of exterior grade plywood\nor waferboard\n•\nOne 4-ft. x 8-ft. sheet interior paneling or thin plywood\nOne package roofing shingles or enough to cover\n8-sq. ft. roof\n•\nTwo 2-in. x 3-in. x 6-ft. untreated lumber\nLinoleum or other floor tiles (to cover 6-sq. ft. floor)\n•\nOne quart exterior house paint\nTwo medium hinges (“T” or gate hinges)\n•\nFifty 2-in. flat head wood screws or grippers\nFour to nine bricks for foundation\n•\nSmall roofing nails (approximately 15)\nFiberglass insulation (1 roll, or enough to cover 14-20 sq. ft.)\nTools Needed\n•\nHammer\nSaw\n•\nElectric screw\ndriver\n•\nAngle brace or\nT-square\n•\nStaple gun\nMeasuring tape\n•\nMarking pen\nThings to consider before starting your project\nThese will help you determine what you need to buy and\nhow much work will be involved, and also provide a few\nhelpful hints.\n•\nHow many cats do you need to house? This number\ndetemines how many shelters to build. Keep in mind that\nnot all cats are likely to use the shelter, or at least not all at\nthe same time. This shelter should probably house no more\nthan five to seven cats at once. You can adjust this plan\nto make a larger shelter, or build more than one shelter\nas needed.\nCaregiving\nInformation\nA\nlley Cat Allies recommends that feral cat colonies have proper protection from inclement weather.\nFollowing are detailed instructions needed to build a feral cat shelter. These building plans are\nrecommended for use throughout the United States. For extremely harsh, cold, and wet climates,\ninsulation (as described) is advised. Other types of shelters, such as dog igloos, can be used in less\nharsh climates. Go to www.alleycat.org/BuildaShelter for additional shelter ideas.\nCompleted shelter\nCaregiving Information\n317P\nFact Sheet:\nwww.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017\nBUILD AN INEXPENSIVE CAT SHELTER, page 2 of 4\n•\nBe sure to make the shelter small enough for transport in\nyour vehicle. The shelter size described here will fit in a\nstandard size car trunk with the trunk lid open.\n•\nIf you live in a climate that gets very cold, we recommend\nthat you use insulation as described in the plans.\n•\nUse only exterior paint to reduce weather exposure,\npreferably dark green or dark brown to match natural\nsurroundings.\n•\nFloor should have linoleum or tile square instead of\ncarpet to reduce the chance of flea infestation. Carpets and\ntowels retain moisture and should not be used.\nAssembly\n1.\nCut wood. For easy assembly, cut all wood first, then\nassemble the shelter. Some pieces may need adjustment\nafter cutting.\nCut plywood as shown at right. (This is only enough for\none shelter.)\nCut paneling as shown at right. One sheet of paneling\nis enough for two shelters.\nCut 2-in. x 3-in. x 6-ft. lumber into eight posts and\ntwo shelf braces as shown at right.\n•\nUse screws, not nails, for better durability.\nRoof should be hinged so bedding can be replaced, and\nfor easy access when retrieving kittens who may be in\nthe shelter.\n•\nRoof must be slanted to drain off water.\nA wind block should be placed inside the door of the shelter\nto improve warmth. You may also consider a canvas flap to\ngo over the door.\n•\nPlace wood chips or straw inside for warmth and comfort.\nBlankets, towels, and carpets retain moisture.\nPlywood Cutting Guidelines\nPaneling Cutting Guidelines\nLumber Cutting Guidelines\nFact Sheet:\nwww.alleycat.org • 7920 ...
#   'filepaths': [PosixPath('/Users/osilkin/Programming/labrador/sdg/notebooks/None/cat-shelter.pdf')],
#   'domain': 'cat-shelter',
#   'document_outline': 'Details on building a feral cat shelter.\n'},
#  {'questions_and_answers': [{'question': 'How many cats can a feral cat shelter house?\n',
#     'answer': 'A feral cat shelter should probably house no more\nthan five to seven cats at once.\n'},
#    {'question': 'What is the best way to determine how many shelters to build?\n',
#     'answer': 'The number of cats you need to house determines how many shelters to build.\n'},
#    {'question': 'What materials are needed to build a feral cat shelter?\n',
#     'answer': 'One 4-ft. x 1/2-in x 8-ft. sheet of exterior grade plywood\nor waferboard, one 4-ft. x 8-ft. sheet interior paneling or thin plywood,\n'}],
#   'context': 'Materials Needed\n• One 4-ft. x 1/2-in x 8-ft. sheet of exterior grade plywood\nor waferboard\n• One 4-ft. x 8-ft. sheet interior paneling or thin plywood\n• One package roofing shingles or enough to cover\n8-sq. ft. roof\n• Two 2-in. x 3-in. x 6-ft. untreated lumber\n• Linoleum or other floor tiles (to cover 6-sq. ft. floor)\n• One quart exterior house paint\n• Two medium hinges (“T” or gate hinges)\n• Fifty 2-in. flat head wood screws or grippers\n• Four to nine bricks for foundation\n• Small roofing nails (approximately 15)\n• Fiberglass insulation (1 roll, or enough to cover 14-20 sq. ft.)\n',
#   'taxonomy_path': '/->Users->osilkin->Programming->labrador->sdg->notebooks->cat-shelter-example',
#   'documents': ['www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017\nBUILD AN INEXPENSIVE CAT SHELTER\nThe following instructions are for building an\ninsulated cat shelter 2 ft. x 3 ft. x 18in. high.\nYou should be able to buy the materials at a local lumberyard.\nAn electric saw and screwdriver are highly recommended.\nCaution: If you are not experienced with an electric saw, ask a\nskilled person to cut the wood and paneling.\nMaterials Needed\n•\nOne 4-ft. x 1/2-in x 8-ft. sheet of exterior grade plywood\nor waferboard\n•\nOne 4-ft. x 8-ft. sheet interior paneling or thin plywood\nOne package roofing shingles or enough to cover\n8-sq. ft. roof\n•\nTwo 2-in. x 3-in. x 6-ft. untreated lumber\nLinoleum or other floor tiles (to cover 6-sq. ft. floor)\n•\nOne quart exterior house paint\nTwo medium hinges (“T” or gate hinges)\n•\nFifty 2-in. flat head wood screws or grippers\nFour to nine bricks for foundation\n•\nSmall roofing nails (approximately 15)\nFiberglass insulation (1 roll, or enough to cover 14-20 sq. ft.)\nTools Needed\n•\nHammer\nSaw\n•\nElectric screw\ndriver\n•\nAngle brace or\nT-square\n•\nStaple gun\nMeasuring tape\n•\nMarking pen\nThings to consider before starting your project\nThese will help you determine what you need to buy and\nhow much work will be involved, and also provide a few\nhelpful hints.\n•\nHow many cats do you need to house? This number\ndetemines how many shelters to build. Keep in mind that\nnot all cats are likely to use the shelter, or at least not all at\nthe same time. This shelter should probably house no more\nthan five to seven cats at once. You can adjust this plan\nto make a larger shelter, or build more than one shelter\nas needed.\nCaregiving\nInformation\nA\nlley Cat Allies recommends that feral cat colonies have proper protection from inclement weather.\nFollowing are detailed instructions needed to build a feral cat shelter. These building plans are\nrecommended for use throughout the United States. For extremely harsh, cold, and wet climates,\ninsulation (as described) is advised. Other types of shelters, such as dog igloos, can be used in less\nharsh climates. Go to www.alleycat.org/BuildaShelter for additional shelter ideas.\nCompleted shelter\nCaregiving Information\n317P\nFact Sheet:\nwww.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017\nBUILD AN INEXPENSIVE CAT SHELTER, page 2 of 4\n•\nBe sure to make the shelter small enough for transport in\nyour vehicle. The shelter size described here will fit in a\nstandard size car trunk with the trunk lid open.\n•\nIf you live in a climate that gets very cold, we recommend\nthat you use insulation as described in the plans.\n•\nUse only exterior paint to reduce weather exposure,\npreferably dark green or dark brown to match natural\nsurroundings.\n•\nFloor should have linoleum or tile square instead of\ncarpet to reduce the chance of flea infestation. Carpets and\ntowels retain moisture and should not be used.\nAssembly\n1.\nCut wood. For easy assembly, cut all wood first, then\nassemble the shelter. Some pieces may need adjustment\nafter cutting.\nCut plywood as shown at right. (This is only enough for\none shelter.)\nCut paneling as shown at right. One sheet of paneling\nis enough for two shelters.\nCut 2-in. x 3-in. x 6-ft. lumber into eight posts and\ntwo shelf braces as shown at right.\n•\nUse screws, not nails, for better durability.\nRoof should be hinged so bedding can be replaced, and\nfor easy access when retrieving kittens who may be in\nthe shelter.\n•\nRoof must be slanted to drain off water.\nA wind block should be placed inside the door of the shelter\nto improve warmth. You may also consider a canvas flap to\ngo over the door.\n•\nPlace wood chips or straw inside for warmth and comfort.\nBlankets, towels, and carpets retain moisture.\nPlywood Cutting Guidelines\nPaneling Cutting Guidelines\nLumber Cutting Guidelines\nFact Sheet:\nwww.alleycat.org • 7920 ...
#   'filepaths': [PosixPath('/Users/osilkin/Programming/labrador/sdg/notebooks/None/cat-shelter.pdf')],
#   'domain': 'cat-shelter',
#   'document_outline': 'Details on building a feral cat shelter.\n'}]

# %%
sample = data[0]
print(sample.keys())
# Out:
# dict_keys(['questions_and_answers', 'context', 'taxonomy_path', 'documents', 'filepaths', 'domain', 'document_outline'])

# %%
sample
# Out:
# {'questions_and_answers': [{'question': 'What is a feral cat shelter?\n',
#    'answer': 'A feral cat shelter is a structure designed to provide protection from inclement weather for feral cat colonies.\n'},
#   {'question': 'What is the mission of Alley Cat Allies?\n',
#    'answer': 'Alley Cat Allies is a nonprofit organization dedicated to promoting the humane treatment of feral and free-roaming cats.\n'},
#   {'question': 'What types of shelters are recommended for feral cat colonies?\n',
#    'answer': 'Dog igloos can be used in less harsh climates.\nFor extremely harsh, cold, and wet climates, insulation is advised.\n'}],
#  'context': 'Alley Cat Allies recommends that feral cat colonies have proper protection from inclement weather.\nFollowing are detailed instructions needed to build a feral cat shelter. These building plans are\nrecommended for use throughout the United States. For extremely harsh, cold, and wet climates,\ninsulation (as described) is advised. Other types of shelters, such as dog igloos, can be used in less\nharsh climates. Go to www.alleycat.org/BuildaShelter for additional shelter ideas.\n',
#  'taxonomy_path': '/->Users->osilkin->Programming->labrador->sdg->notebooks->cat-shelter-example',
#  'documents': ['www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017\nBUILD AN INEXPENSIVE CAT SHELTER\nThe following instructions are for building an\ninsulated cat shelter 2 ft. x 3 ft. x 18in. high.\nYou should be able to buy the materials at a local lumberyard.\nAn electric saw and screwdriver are highly recommended.\nCaution: If you are not experienced with an electric saw, ask a\nskilled person to cut the wood and paneling.\nMaterials Needed\n•\nOne 4-ft. x 1/2-in x 8-ft. sheet of exterior grade plywood\nor waferboard\n•\nOne 4-ft. x 8-ft. sheet interior paneling or thin plywood\nOne package roofing shingles or enough to cover\n8-sq. ft. roof\n•\nTwo 2-in. x 3-in. x 6-ft. untreated lumber\nLinoleum or other floor tiles (to cover 6-sq. ft. floor)\n•\nOne quart exterior house paint\nTwo medium hinges (“T” or gate hinges)\n•\nFifty 2-in. flat head wood screws or grippers\nFour to nine bricks for foundation\n•\nSmall roofing nails (approximately 15)\nFiberglass insulation (1 roll, or enough to cover 14-20 sq. ft.)\nTools Needed\n•\nHammer\nSaw\n•\nElectric screw\ndriver\n•\nAngle brace or\nT-square\n•\nStaple gun\nMeasuring tape\n•\nMarking pen\nThings to consider before starting your project\nThese will help you determine what you need to buy and\nhow much work will be involved, and also provide a few\nhelpful hints.\n•\nHow many cats do you need to house? This number\ndetemines how many shelters to build. Keep in mind that\nnot all cats are likely to use the shelter, or at least not all at\nthe same time. This shelter should probably house no more\nthan five to seven cats at once. You can adjust this plan\nto make a larger shelter, or build more than one shelter\nas needed.\nCaregiving\nInformation\nA\nlley Cat Allies recommends that feral cat colonies have proper protection from inclement weather.\nFollowing are detailed instructions needed to build a feral cat shelter. These building plans are\nrecommended for use throughout the United States. For extremely harsh, cold, and wet climates,\ninsulation (as described) is advised. Other types of shelters, such as dog igloos, can be used in less\nharsh climates. Go to www.alleycat.org/BuildaShelter for additional shelter ideas.\nCompleted shelter\nCaregiving Information\n317P\nFact Sheet:\nwww.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017\nBUILD AN INEXPENSIVE CAT SHELTER, page 2 of 4\n•\nBe sure to make the shelter small enough for transport in\nyour vehicle. The shelter size described here will fit in a\nstandard size car trunk with the trunk lid open.\n•\nIf you live in a climate that gets very cold, we recommend\nthat you use insulation as described in the plans.\n•\nUse only exterior paint to reduce weather exposure,\npreferably dark green or dark brown to match natural\nsurroundings.\n•\nFloor should have linoleum or tile square instead of\ncarpet to reduce the chance of flea infestation. Carpets and\ntowels retain moisture and should not be used.\nAssembly\n1.\nCut wood. For easy assembly, cut all wood first, then\nassemble the shelter. Some pieces may need adjustment\nafter cutting.\nCut plywood as shown at right. (This is only enough for\none shelter.)\nCut paneling as shown at right. One sheet of paneling\nis enough for two shelters.\nCut 2-in. x 3-in. x 6-ft. lumber into eight posts and\ntwo shelf braces as shown at right.\n•\nUse screws, not nails, for better durability.\nRoof should be hinged so bedding can be replaced, and\nfor easy access when retrieving kittens who may be in\nthe shelter.\n•\nRoof must be slanted to drain off water.\nA wind block should be placed inside the door of the shelter\nto improve warmth. You may also consider a canvas flap to\ngo over the door.\n•\nPlace wood chips or straw inside for warmth and comfort.\nBlankets, towels, and carpets retain moisture.\nPlywood Cutting Guidelines\nPaneling Cutting Guidelines\nLumber Cutting Guidelines\nFact Sheet:\nwww.alleycat.org • 7920  ...
#  'filepaths': [PosixPath('/Users/osilkin/Programming/labrador/sdg/notebooks/None/cat-shelter.pdf')],
#  'domain': 'cat-shelter',
#  'document_outline': 'Details on building a feral cat shelter.\n'}

# %% [markdown]
# As in the previous example, we have a listing of various items from the `qna.yaml`. But now the `.documents` field contains a list of the documents including our parsed PDF

# %%
from IPython.display import display, Markdown


# Display it as rendered markdown
# display(Markdown(sample['documents'][0]))
print(sample['documents'][0])
# Out:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# BUILD AN INEXPENSIVE CAT SHELTER
# The following instructions are for building an
# insulated cat shelter 2 ft. x 3 ft. x 18in. high.
# You should be able to buy the materials at a local lumberyard.
# An electric saw and screwdriver are highly recommended.
# Caution: If you are not experienced with an electric saw, ask a
# skilled person to cut the wood and paneling.
# Materials Needed
# •
# One 4-ft. x 1/2-in x 8-ft. sheet of exterior grade plywood
# or waferboard
# •
# One 4-ft. x 8-ft. sheet interior paneling or thin plywood
# One package roofing shingles or enough to cover
# 8-sq. ft. roof
# •
# Two 2-in. x 3-in. x 6-ft. untreated lumber
# Linoleum or other floor tiles (to cover 6-sq. ft. floor)
# •
# One quart exterior house paint
# Two medium hinges (“T” or gate hinges)
# •
# Fifty 2-in. flat head wood screws or grippers
# Four to nine bricks for foundation
# •
# Small roofing nails (approximately 15)
# Fiberglass insulation (1 roll, or enough to cover 14-20 sq. ft.)
# Tools Needed
# •
# Hammer
# Saw
# •
# Electric screw
# driver
# •
# Angle brace or
# T-square
# •
# Staple gun
# Measuring tape
# •
# Marking pen
# Things to consider before starting your project
# These will help you determine what you need to buy and
# how much work will be involved, and also provide a few
# helpful hints.
# •
# How many cats do you need to house? This number
# detemines how many shelters to build. Keep in mind that
# not all cats are likely to use the shelter, or at least not all at
# the same time. This shelter should probably house no more
# than five to seven cats at once. You can adjust this plan
# to make a larger shelter, or build more than one shelter
# as needed.
# Caregiving
# Information
# A
# lley Cat Allies recommends that feral cat colonies have proper protection from inclement weather.
# Following are detailed instructions needed to build a feral cat shelter. These building plans are
# recommended for use throughout the United States. For extremely harsh, cold, and wet climates,
# insulation (as described) is advised. Other types of shelters, such as dog igloos, can be used in less
# harsh climates. Go to www.alleycat.org/BuildaShelter for additional shelter ideas.
# Completed shelter
# Caregiving Information
# 317P
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# BUILD AN INEXPENSIVE CAT SHELTER, page 2 of 4
# •
# Be sure to make the shelter small enough for transport in
# your vehicle. The shelter size described here will fit in a
# standard size car trunk with the trunk lid open.
# •
# If you live in a climate that gets very cold, we recommend
# that you use insulation as described in the plans.
# •
# Use only exterior paint to reduce weather exposure,
# preferably dark green or dark brown to match natural
# surroundings.
# •
# Floor should have linoleum or tile square instead of
# carpet to reduce the chance of flea infestation. Carpets and
# towels retain moisture and should not be used.
# Assembly
# 1.
# Cut wood. For easy assembly, cut all wood first, then
# assemble the shelter. Some pieces may need adjustment
# after cutting.
# Cut plywood as shown at right. (This is only enough for
# one shelter.)
# Cut paneling as shown at right. One sheet of paneling
# is enough for two shelters.
# Cut 2-in. x 3-in. x 6-ft. lumber into eight posts and
# two shelf braces as shown at right.
# •
# Use screws, not nails, for better durability.
# Roof should be hinged so bedding can be replaced, and
# for easy access when retrieving kittens who may be in
# the shelter.
# •
# Roof must be slanted to drain off water.
# A wind block should be placed inside the door of the shelter
# to improve warmth. You may also consider a canvas flap to
# go over the door.
# •
# Place wood chips or straw inside for warmth and comfort.
# Blankets, towels, and carpets retain moisture.
# Plywood Cutting Guidelines
# Paneling Cutting Guidelines
# Lumber Cutting Guidelines
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# 2.
# Put side wall A in place on the left of the base and screw
# front wall and left side wall together using one 17-in. corner
# post.
# 3.
# Position side wall B on the right and attach to front wall
# using other 17-in. corner post.
# 4.
# Position back wall and attach to both side walls using two
# 11-in. corner posts.
# Note:
# Corner posts should rest on
# top of the base, as should the front, back, and side walls.
# All posts should be inside of the front, back, and side walls.
# 5.
# Turn walls upside down and place the 3-ft. x 2-ft. base on
# top. Mount base to sides, first screwing down corners then
# going along edges. Be careful that screws go straight into
# plywood walls, without protruding through sides.
# 6.
# Turn the shelter back to upright position.
# 7.
# Cut and staple insulation blueboard to inside of side walls A
# and B.
# 8.
# Attach front and back posts for front and back wall supports.
# Note that the posts are placed flat against the front and back
# walls, at right angles to the corner posts, as shown. The post
# next to the front door should be 5-1/2 inches from the right
# interior wall to leave room for the wind block.
# 9.
# Cut and staple the remaining insulation to the inside of
# front and back walls.
# 10.
# Put the wind block in place and screw it to the front of the
# shelter, then to bottom (do this from outside in).
# 11.
# For extra cat sleeping room, screw 5-in. shelf braces upright
# to the center of wind block and left interior wall near the
# front corner of shelter to support shelf, if desired. Then
# screw 9-in. x 2-ft. 3.5-in. shelf on top of braces.
# 12.
# Place the 2-ft. 7-in. x 3-ft. 3-in. roof on bench and turn
# shelter upside down. Center shelter on the roof with roof
# hanging over on all sides. Screw hinges to the underside of
# the roof and outside the front of the shelter so it will open
# easily and stand up straight on its own.
# 13.
# Turn the shelter back over and attach shingles with roofing
# nails in an offset pattern to seal against weather. After nailing
# shingles bend nail points over to avoid injuring cats.
# BUILD AN INEXPENSIVE CAT SHELTER, page 3 of 4
# FRONT
# BACK
# A
# B
# 11” POST
# 11” POST
# 17” POST
# 17” POST
# Steps 1-6
# FRONT
# BACK
# A
# B
# POST
# POST
# POST
# POST
# I
# N
# S
# U
# L
# A
# T
# I
# O
# N
# I
# N
# S
# U
# L
# A
# T
# I
# O
# N
# Steps 7-8
# FRONT
# BACK
# INSULATION
# WINDBLOCK
# INSULATION
# Steps 9-10
# SHELF
# Step 11
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# 14.
# Place the vinyl floor tiles inside if desired for extra protection.
# 15.
# Paint the shelter (all exposed wood should be painted,
# including bottom, to protect it from rain and/or snow).
# 16.When installing the shelter, make sure to set it on top of
# bricks or other objects to keep it away from ground contact.
# Also take prevailing winds and exposure into account; placing
# shelter front facing south often maximizes warmth.
# Note:
# You may also cover the interior underside of the roof
# with fiberglass or plastic foam insulation, but be sure to cover
# it with plastic or wood. Foam needs to be covered to hold it in
# place, and uncovered fiberglass will harm cats. You can insulate
# the shelter with strong plastic to keep out wind, rain, and cold.
# Leave a small opening for the cats to enter. A flap can be placed
# over the entrance for added protection.
# BUILD AN INEXPENSIVE CAT SHELTER, page 4 of 4
# Shelter design and construction drawings by Bill McFadden and Ken Crawford.
# Shelter illustration by Doug Hall.
# Shelter Interior
# Shelter Exterior

# %% [markdown]
# Here we see the PDF was attempted to be parsed, but we ran into issues due to the formatting of the PDF document, showing that we cannot always perfectly parse documents when dealing with PDFs.

# %%
for sample in data:
  print(sample['documents'][0], end=('\n' + '=' * 200))
# Out:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# BUILD AN INEXPENSIVE CAT SHELTER
# The following instructions are for building an
# insulated cat shelter 2 ft. x 3 ft. x 18in. high.
# You should be able to buy the materials at a local lumberyard.
# An electric saw and screwdriver are highly recommended.
# Caution: If you are not experienced with an electric saw, ask a
# skilled person to cut the wood and paneling.
# Materials Needed
# •
# One 4-ft. x 1/2-in x 8-ft. sheet of exterior grade plywood
# or waferboard
# •
# One 4-ft. x 8-ft. sheet interior paneling or thin plywood
# One package roofing shingles or enough to cover
# 8-sq. ft. roof
# •
# Two 2-in. x 3-in. x 6-ft. untreated lumber
# Linoleum or other floor tiles (to cover 6-sq. ft. floor)
# •
# One quart exterior house paint
# Two medium hinges (“T” or gate hinges)
# •
# Fifty 2-in. flat head wood screws or grippers
# Four to nine bricks for foundation
# •
# Small roofing nails (approximately 15)
# Fiberglass insulation (1 roll, or enough to cover 14-20 sq. ft.)
# Tools Needed
# •
# Hammer
# Saw
# •
# Electric screw
# driver
# •
# Angle brace or
# T-square
# •
# Staple gun
# Measuring tape
# •
# Marking pen
# Things to consider before starting your project
# These will help you determine what you need to buy and
# how much work will be involved, and also provide a few
# helpful hints.
# •
# How many cats do you need to house? This number
# detemines how many shelters to build. Keep in mind that
# not all cats are likely to use the shelter, or at least not all at
# the same time. This shelter should probably house no more
# than five to seven cats at once. You can adjust this plan
# to make a larger shelter, or build more than one shelter
# as needed.
# Caregiving
# Information
# A
# lley Cat Allies recommends that feral cat colonies have proper protection from inclement weather.
# Following are detailed instructions needed to build a feral cat shelter. These building plans are
# recommended for use throughout the United States. For extremely harsh, cold, and wet climates,
# insulation (as described) is advised. Other types of shelters, such as dog igloos, can be used in less
# harsh climates. Go to www.alleycat.org/BuildaShelter for additional shelter ideas.
# Completed shelter
# Caregiving Information
# 317P
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# BUILD AN INEXPENSIVE CAT SHELTER, page 2 of 4
# •
# Be sure to make the shelter small enough for transport in
# your vehicle. The shelter size described here will fit in a
# standard size car trunk with the trunk lid open.
# •
# If you live in a climate that gets very cold, we recommend
# that you use insulation as described in the plans.
# •
# Use only exterior paint to reduce weather exposure,
# preferably dark green or dark brown to match natural
# surroundings.
# •
# Floor should have linoleum or tile square instead of
# carpet to reduce the chance of flea infestation. Carpets and
# towels retain moisture and should not be used.
# Assembly
# 1.
# Cut wood. For easy assembly, cut all wood first, then
# assemble the shelter. Some pieces may need adjustment
# after cutting.
# Cut plywood as shown at right. (This is only enough for
# one shelter.)
# Cut paneling as shown at right. One sheet of paneling
# is enough for two shelters.
# Cut 2-in. x 3-in. x 6-ft. lumber into eight posts and
# two shelf braces as shown at right.
# •
# Use screws, not nails, for better durability.
# Roof should be hinged so bedding can be replaced, and
# for easy access when retrieving kittens who may be in
# the shelter.
# •
# Roof must be slanted to drain off water.
# A wind block should be placed inside the door of the shelter
# to improve warmth. You may also consider a canvas flap to
# go over the door.
# •
# Place wood chips or straw inside for warmth and comfort.
# Blankets, towels, and carpets retain moisture.
# Plywood Cutting Guidelines
# Paneling Cutting Guidelines
# Lumber Cutting Guidelines
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# 2.
# Put side wall A in place on the left of the base and screw
# front wall and left side wall together using one 17-in. corner
# post.
# 3.
# Position side wall B on the right and attach to front wall
# using other 17-in. corner post.
# 4.
# Position back wall and attach to both side walls using two
# 11-in. corner posts.
# Note:
# Corner posts should rest on
# top of the base, as should the front, back, and side walls.
# All posts should be inside of the front, back, and side walls.
# 5.
# Turn walls upside down and place the 3-ft. x 2-ft. base on
# top. Mount base to sides, first screwing down corners then
# going along edges. Be careful that screws go straight into
# plywood walls, without protruding through sides.
# 6.
# Turn the shelter back to upright position.
# 7.
# Cut and staple insulation blueboard to inside of side walls A
# and B.
# 8.
# Attach front and back posts for front and back wall supports.
# Note that the posts are placed flat against the front and back
# walls, at right angles to the corner posts, as shown. The post
# next to the front door should be 5-1/2 inches from the right
# interior wall to leave room for the wind block.
# 9.
# Cut and staple the remaining insulation to the inside of
# front and back walls.
# 10.
# Put the wind block in place and screw it to the front of the
# shelter, then to bottom (do this from outside in).
# 11.
# For extra cat sleeping room, screw 5-in. shelf braces upright
# to the center of wind block and left interior wall near the
# front corner of shelter to support shelf, if desired. Then
# screw 9-in. x 2-ft. 3.5-in. shelf on top of braces.
# 12.
# Place the 2-ft. 7-in. x 3-ft. 3-in. roof on bench and turn
# shelter upside down. Center shelter on the roof with roof
# hanging over on all sides. Screw hinges to the underside of
# the roof and outside the front of the shelter so it will open
# easily and stand up straight on its own.
# 13.
# Turn the shelter back over and attach shingles with roofing
# nails in an offset pattern to seal against weather. After nailing
# shingles bend nail points over to avoid injuring cats.
# BUILD AN INEXPENSIVE CAT SHELTER, page 3 of 4
# FRONT
# BACK
# A
# B
# 11” POST
# 11” POST
# 17” POST
# 17” POST
# Steps 1-6
# FRONT
# BACK
# A
# B
# POST
# POST
# POST
# POST
# I
# N
# S
# U
# L
# A
# T
# I
# O
# N
# I
# N
# S
# U
# L
# A
# T
# I
# O
# N
# Steps 7-8
# FRONT
# BACK
# INSULATION
# WINDBLOCK
# INSULATION
# Steps 9-10
# SHELF
# Step 11
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# 14.
# Place the vinyl floor tiles inside if desired for extra protection.
# 15.
# Paint the shelter (all exposed wood should be painted,
# including bottom, to protect it from rain and/or snow).
# 16.When installing the shelter, make sure to set it on top of
# bricks or other objects to keep it away from ground contact.
# Also take prevailing winds and exposure into account; placing
# shelter front facing south often maximizes warmth.
# Note:
# You may also cover the interior underside of the roof
# with fiberglass or plastic foam insulation, but be sure to cover
# it with plastic or wood. Foam needs to be covered to hold it in
# place, and uncovered fiberglass will harm cats. You can insulate
# the shelter with strong plastic to keep out wind, rain, and cold.
# Leave a small opening for the cats to enter. A flap can be placed
# over the entrance for added protection.
# BUILD AN INEXPENSIVE CAT SHELTER, page 4 of 4
# Shelter design and construction drawings by Bill McFadden and Ken Crawford.
# Shelter illustration by Doug Hall.
# Shelter Interior
# Shelter Exterior
#
# ========================================================================================================================================================================================================www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# BUILD AN INEXPENSIVE CAT SHELTER
# The following instructions are for building an
# insulated cat shelter 2 ft. x 3 ft. x 18in. high.
# You should be able to buy the materials at a local lumberyard.
# An electric saw and screwdriver are highly recommended.
# Caution: If you are not experienced with an electric saw, ask a
# skilled person to cut the wood and paneling.
# Materials Needed
# •
# One 4-ft. x 1/2-in x 8-ft. sheet of exterior grade plywood
# or waferboard
# •
# One 4-ft. x 8-ft. sheet interior paneling or thin plywood
# One package roofing shingles or enough to cover
# 8-sq. ft. roof
# •
# Two 2-in. x 3-in. x 6-ft. untreated lumber
# Linoleum or other floor tiles (to cover 6-sq. ft. floor)
# •
# One quart exterior house paint
# Two medium hinges (“T” or gate hinges)
# •
# Fifty 2-in. flat head wood screws or grippers
# Four to nine bricks for foundation
# •
# Small roofing nails (approximately 15)
# Fiberglass insulation (1 roll, or enough to cover 14-20 sq. ft.)
# Tools Needed
# •
# Hammer
# Saw
# •
# Electric screw
# driver
# •
# Angle brace or
# T-square
# •
# Staple gun
# Measuring tape
# •
# Marking pen
# Things to consider before starting your project
# These will help you determine what you need to buy and
# how much work will be involved, and also provide a few
# helpful hints.
# •
# How many cats do you need to house? This number
# detemines how many shelters to build. Keep in mind that
# not all cats are likely to use the shelter, or at least not all at
# the same time. This shelter should probably house no more
# than five to seven cats at once. You can adjust this plan
# to make a larger shelter, or build more than one shelter
# as needed.
# Caregiving
# Information
# A
# lley Cat Allies recommends that feral cat colonies have proper protection from inclement weather.
# Following are detailed instructions needed to build a feral cat shelter. These building plans are
# recommended for use throughout the United States. For extremely harsh, cold, and wet climates,
# insulation (as described) is advised. Other types of shelters, such as dog igloos, can be used in less
# harsh climates. Go to www.alleycat.org/BuildaShelter for additional shelter ideas.
# Completed shelter
# Caregiving Information
# 317P
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# BUILD AN INEXPENSIVE CAT SHELTER, page 2 of 4
# •
# Be sure to make the shelter small enough for transport in
# your vehicle. The shelter size described here will fit in a
# standard size car trunk with the trunk lid open.
# •
# If you live in a climate that gets very cold, we recommend
# that you use insulation as described in the plans.
# •
# Use only exterior paint to reduce weather exposure,
# preferably dark green or dark brown to match natural
# surroundings.
# •
# Floor should have linoleum or tile square instead of
# carpet to reduce the chance of flea infestation. Carpets and
# towels retain moisture and should not be used.
# Assembly
# 1.
# Cut wood. For easy assembly, cut all wood first, then
# assemble the shelter. Some pieces may need adjustment
# after cutting.
# Cut plywood as shown at right. (This is only enough for
# one shelter.)
# Cut paneling as shown at right. One sheet of paneling
# is enough for two shelters.
# Cut 2-in. x 3-in. x 6-ft. lumber into eight posts and
# two shelf braces as shown at right.
# •
# Use screws, not nails, for better durability.
# Roof should be hinged so bedding can be replaced, and
# for easy access when retrieving kittens who may be in
# the shelter.
# •
# Roof must be slanted to drain off water.
# A wind block should be placed inside the door of the shelter
# to improve warmth. You may also consider a canvas flap to
# go over the door.
# •
# Place wood chips or straw inside for warmth and comfort.
# Blankets, towels, and carpets retain moisture.
# Plywood Cutting Guidelines
# Paneling Cutting Guidelines
# Lumber Cutting Guidelines
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# 2.
# Put side wall A in place on the left of the base and screw
# front wall and left side wall together using one 17-in. corner
# post.
# 3.
# Position side wall B on the right and attach to front wall
# using other 17-in. corner post.
# 4.
# Position back wall and attach to both side walls using two
# 11-in. corner posts.
# Note:
# Corner posts should rest on
# top of the base, as should the front, back, and side walls.
# All posts should be inside of the front, back, and side walls.
# 5.
# Turn walls upside down and place the 3-ft. x 2-ft. base on
# top. Mount base to sides, first screwing down corners then
# going along edges. Be careful that screws go straight into
# plywood walls, without protruding through sides.
# 6.
# Turn the shelter back to upright position.
# 7.
# Cut and staple insulation blueboard to inside of side walls A
# and B.
# 8.
# Attach front and back posts for front and back wall supports.
# Note that the posts are placed flat against the front and back
# walls, at right angles to the corner posts, as shown. The post
# next to the front door should be 5-1/2 inches from the right
# interior wall to leave room for the wind block.
# 9.
# Cut and staple the remaining insulation to the inside of
# front and back walls.
# 10.
# Put the wind block in place and screw it to the front of the
# shelter, then to bottom (do this from outside in).
# 11.
# For extra cat sleeping room, screw 5-in. shelf braces upright
# to the center of wind block and left interior wall near the
# front corner of shelter to support shelf, if desired. Then
# screw 9-in. x 2-ft. 3.5-in. shelf on top of braces.
# 12.
# Place the 2-ft. 7-in. x 3-ft. 3-in. roof on bench and turn
# shelter upside down. Center shelter on the roof with roof
# hanging over on all sides. Screw hinges to the underside of
# the roof and outside the front of the shelter so it will open
# easily and stand up straight on its own.
# 13.
# Turn the shelter back over and attach shingles with roofing
# nails in an offset pattern to seal against weather. After nailing
# shingles bend nail points over to avoid injuring cats.
# BUILD AN INEXPENSIVE CAT SHELTER, page 3 of 4
# FRONT
# BACK
# A
# B
# 11” POST
# 11” POST
# 17” POST
# 17” POST
# Steps 1-6
# FRONT
# BACK
# A
# B
# POST
# POST
# POST
# POST
# I
# N
# S
# U
# L
# A
# T
# I
# O
# N
# I
# N
# S
# U
# L
# A
# T
# I
# O
# N
# Steps 7-8
# FRONT
# BACK
# INSULATION
# WINDBLOCK
# INSULATION
# Steps 9-10
# SHELF
# Step 11
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# 14.
# Place the vinyl floor tiles inside if desired for extra protection.
# 15.
# Paint the shelter (all exposed wood should be painted,
# including bottom, to protect it from rain and/or snow).
# 16.When installing the shelter, make sure to set it on top of
# bricks or other objects to keep it away from ground contact.
# Also take prevailing winds and exposure into account; placing
# shelter front facing south often maximizes warmth.
# Note:
# You may also cover the interior underside of the roof
# with fiberglass or plastic foam insulation, but be sure to cover
# it with plastic or wood. Foam needs to be covered to hold it in
# place, and uncovered fiberglass will harm cats. You can insulate
# the shelter with strong plastic to keep out wind, rain, and cold.
# Leave a small opening for the cats to enter. A flap can be placed
# over the entrance for added protection.
# BUILD AN INEXPENSIVE CAT SHELTER, page 4 of 4
# Shelter design and construction drawings by Bill McFadden and Ken Crawford.
# Shelter illustration by Doug Hall.
# Shelter Interior
# Shelter Exterior
#
# ========================================================================================================================================================================================================www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# BUILD AN INEXPENSIVE CAT SHELTER
# The following instructions are for building an
# insulated cat shelter 2 ft. x 3 ft. x 18in. high.
# You should be able to buy the materials at a local lumberyard.
# An electric saw and screwdriver are highly recommended.
# Caution: If you are not experienced with an electric saw, ask a
# skilled person to cut the wood and paneling.
# Materials Needed
# •
# One 4-ft. x 1/2-in x 8-ft. sheet of exterior grade plywood
# or waferboard
# •
# One 4-ft. x 8-ft. sheet interior paneling or thin plywood
# One package roofing shingles or enough to cover
# 8-sq. ft. roof
# •
# Two 2-in. x 3-in. x 6-ft. untreated lumber
# Linoleum or other floor tiles (to cover 6-sq. ft. floor)
# •
# One quart exterior house paint
# Two medium hinges (“T” or gate hinges)
# •
# Fifty 2-in. flat head wood screws or grippers
# Four to nine bricks for foundation
# •
# Small roofing nails (approximately 15)
# Fiberglass insulation (1 roll, or enough to cover 14-20 sq. ft.)
# Tools Needed
# •
# Hammer
# Saw
# •
# Electric screw
# driver
# •
# Angle brace or
# T-square
# •
# Staple gun
# Measuring tape
# •
# Marking pen
# Things to consider before starting your project
# These will help you determine what you need to buy and
# how much work will be involved, and also provide a few
# helpful hints.
# •
# How many cats do you need to house? This number
# detemines how many shelters to build. Keep in mind that
# not all cats are likely to use the shelter, or at least not all at
# the same time. This shelter should probably house no more
# than five to seven cats at once. You can adjust this plan
# to make a larger shelter, or build more than one shelter
# as needed.
# Caregiving
# Information
# A
# lley Cat Allies recommends that feral cat colonies have proper protection from inclement weather.
# Following are detailed instructions needed to build a feral cat shelter. These building plans are
# recommended for use throughout the United States. For extremely harsh, cold, and wet climates,
# insulation (as described) is advised. Other types of shelters, such as dog igloos, can be used in less
# harsh climates. Go to www.alleycat.org/BuildaShelter for additional shelter ideas.
# Completed shelter
# Caregiving Information
# 317P
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# BUILD AN INEXPENSIVE CAT SHELTER, page 2 of 4
# •
# Be sure to make the shelter small enough for transport in
# your vehicle. The shelter size described here will fit in a
# standard size car trunk with the trunk lid open.
# •
# If you live in a climate that gets very cold, we recommend
# that you use insulation as described in the plans.
# •
# Use only exterior paint to reduce weather exposure,
# preferably dark green or dark brown to match natural
# surroundings.
# •
# Floor should have linoleum or tile square instead of
# carpet to reduce the chance of flea infestation. Carpets and
# towels retain moisture and should not be used.
# Assembly
# 1.
# Cut wood. For easy assembly, cut all wood first, then
# assemble the shelter. Some pieces may need adjustment
# after cutting.
# Cut plywood as shown at right. (This is only enough for
# one shelter.)
# Cut paneling as shown at right. One sheet of paneling
# is enough for two shelters.
# Cut 2-in. x 3-in. x 6-ft. lumber into eight posts and
# two shelf braces as shown at right.
# •
# Use screws, not nails, for better durability.
# Roof should be hinged so bedding can be replaced, and
# for easy access when retrieving kittens who may be in
# the shelter.
# •
# Roof must be slanted to drain off water.
# A wind block should be placed inside the door of the shelter
# to improve warmth. You may also consider a canvas flap to
# go over the door.
# •
# Place wood chips or straw inside for warmth and comfort.
# Blankets, towels, and carpets retain moisture.
# Plywood Cutting Guidelines
# Paneling Cutting Guidelines
# Lumber Cutting Guidelines
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# 2.
# Put side wall A in place on the left of the base and screw
# front wall and left side wall together using one 17-in. corner
# post.
# 3.
# Position side wall B on the right and attach to front wall
# using other 17-in. corner post.
# 4.
# Position back wall and attach to both side walls using two
# 11-in. corner posts.
# Note:
# Corner posts should rest on
# top of the base, as should the front, back, and side walls.
# All posts should be inside of the front, back, and side walls.
# 5.
# Turn walls upside down and place the 3-ft. x 2-ft. base on
# top. Mount base to sides, first screwing down corners then
# going along edges. Be careful that screws go straight into
# plywood walls, without protruding through sides.
# 6.
# Turn the shelter back to upright position.
# 7.
# Cut and staple insulation blueboard to inside of side walls A
# and B.
# 8.
# Attach front and back posts for front and back wall supports.
# Note that the posts are placed flat against the front and back
# walls, at right angles to the corner posts, as shown. The post
# next to the front door should be 5-1/2 inches from the right
# interior wall to leave room for the wind block.
# 9.
# Cut and staple the remaining insulation to the inside of
# front and back walls.
# 10.
# Put the wind block in place and screw it to the front of the
# shelter, then to bottom (do this from outside in).
# 11.
# For extra cat sleeping room, screw 5-in. shelf braces upright
# to the center of wind block and left interior wall near the
# front corner of shelter to support shelf, if desired. Then
# screw 9-in. x 2-ft. 3.5-in. shelf on top of braces.
# 12.
# Place the 2-ft. 7-in. x 3-ft. 3-in. roof on bench and turn
# shelter upside down. Center shelter on the roof with roof
# hanging over on all sides. Screw hinges to the underside of
# the roof and outside the front of the shelter so it will open
# easily and stand up straight on its own.
# 13.
# Turn the shelter back over and attach shingles with roofing
# nails in an offset pattern to seal against weather. After nailing
# shingles bend nail points over to avoid injuring cats.
# BUILD AN INEXPENSIVE CAT SHELTER, page 3 of 4
# FRONT
# BACK
# A
# B
# 11” POST
# 11” POST
# 17” POST
# 17” POST
# Steps 1-6
# FRONT
# BACK
# A
# B
# POST
# POST
# POST
# POST
# I
# N
# S
# U
# L
# A
# T
# I
# O
# N
# I
# N
# S
# U
# L
# A
# T
# I
# O
# N
# Steps 7-8
# FRONT
# BACK
# INSULATION
# WINDBLOCK
# INSULATION
# Steps 9-10
# SHELF
# Step 11
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# 14.
# Place the vinyl floor tiles inside if desired for extra protection.
# 15.
# Paint the shelter (all exposed wood should be painted,
# including bottom, to protect it from rain and/or snow).
# 16.When installing the shelter, make sure to set it on top of
# bricks or other objects to keep it away from ground contact.
# Also take prevailing winds and exposure into account; placing
# shelter front facing south often maximizes warmth.
# Note:
# You may also cover the interior underside of the roof
# with fiberglass or plastic foam insulation, but be sure to cover
# it with plastic or wood. Foam needs to be covered to hold it in
# place, and uncovered fiberglass will harm cats. You can insulate
# the shelter with strong plastic to keep out wind, rain, and cold.
# Leave a small opening for the cats to enter. A flap can be placed
# over the entrance for added protection.
# BUILD AN INEXPENSIVE CAT SHELTER, page 4 of 4
# Shelter design and construction drawings by Bill McFadden and Ken Crawford.
# Shelter illustration by Doug Hall.
# Shelter Interior
# Shelter Exterior
#
# ========================================================================================================================================================================================================www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# BUILD AN INEXPENSIVE CAT SHELTER
# The following instructions are for building an
# insulated cat shelter 2 ft. x 3 ft. x 18in. high.
# You should be able to buy the materials at a local lumberyard.
# An electric saw and screwdriver are highly recommended.
# Caution: If you are not experienced with an electric saw, ask a
# skilled person to cut the wood and paneling.
# Materials Needed
# •
# One 4-ft. x 1/2-in x 8-ft. sheet of exterior grade plywood
# or waferboard
# •
# One 4-ft. x 8-ft. sheet interior paneling or thin plywood
# One package roofing shingles or enough to cover
# 8-sq. ft. roof
# •
# Two 2-in. x 3-in. x 6-ft. untreated lumber
# Linoleum or other floor tiles (to cover 6-sq. ft. floor)
# •
# One quart exterior house paint
# Two medium hinges (“T” or gate hinges)
# •
# Fifty 2-in. flat head wood screws or grippers
# Four to nine bricks for foundation
# •
# Small roofing nails (approximately 15)
# Fiberglass insulation (1 roll, or enough to cover 14-20 sq. ft.)
# Tools Needed
# •
# Hammer
# Saw
# •
# Electric screw
# driver
# •
# Angle brace or
# T-square
# •
# Staple gun
# Measuring tape
# •
# Marking pen
# Things to consider before starting your project
# These will help you determine what you need to buy and
# how much work will be involved, and also provide a few
# helpful hints.
# •
# How many cats do you need to house? This number
# detemines how many shelters to build. Keep in mind that
# not all cats are likely to use the shelter, or at least not all at
# the same time. This shelter should probably house no more
# than five to seven cats at once. You can adjust this plan
# to make a larger shelter, or build more than one shelter
# as needed.
# Caregiving
# Information
# A
# lley Cat Allies recommends that feral cat colonies have proper protection from inclement weather.
# Following are detailed instructions needed to build a feral cat shelter. These building plans are
# recommended for use throughout the United States. For extremely harsh, cold, and wet climates,
# insulation (as described) is advised. Other types of shelters, such as dog igloos, can be used in less
# harsh climates. Go to www.alleycat.org/BuildaShelter for additional shelter ideas.
# Completed shelter
# Caregiving Information
# 317P
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# BUILD AN INEXPENSIVE CAT SHELTER, page 2 of 4
# •
# Be sure to make the shelter small enough for transport in
# your vehicle. The shelter size described here will fit in a
# standard size car trunk with the trunk lid open.
# •
# If you live in a climate that gets very cold, we recommend
# that you use insulation as described in the plans.
# •
# Use only exterior paint to reduce weather exposure,
# preferably dark green or dark brown to match natural
# surroundings.
# •
# Floor should have linoleum or tile square instead of
# carpet to reduce the chance of flea infestation. Carpets and
# towels retain moisture and should not be used.
# Assembly
# 1.
# Cut wood. For easy assembly, cut all wood first, then
# assemble the shelter. Some pieces may need adjustment
# after cutting.
# Cut plywood as shown at right. (This is only enough for
# one shelter.)
# Cut paneling as shown at right. One sheet of paneling
# is enough for two shelters.
# Cut 2-in. x 3-in. x 6-ft. lumber into eight posts and
# two shelf braces as shown at right.
# •
# Use screws, not nails, for better durability.
# Roof should be hinged so bedding can be replaced, and
# for easy access when retrieving kittens who may be in
# the shelter.
# •
# Roof must be slanted to drain off water.
# A wind block should be placed inside the door of the shelter
# to improve warmth. You may also consider a canvas flap to
# go over the door.
# •
# Place wood chips or straw inside for warmth and comfort.
# Blankets, towels, and carpets retain moisture.
# Plywood Cutting Guidelines
# Paneling Cutting Guidelines
# Lumber Cutting Guidelines
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# 2.
# Put side wall A in place on the left of the base and screw
# front wall and left side wall together using one 17-in. corner
# post.
# 3.
# Position side wall B on the right and attach to front wall
# using other 17-in. corner post.
# 4.
# Position back wall and attach to both side walls using two
# 11-in. corner posts.
# Note:
# Corner posts should rest on
# top of the base, as should the front, back, and side walls.
# All posts should be inside of the front, back, and side walls.
# 5.
# Turn walls upside down and place the 3-ft. x 2-ft. base on
# top. Mount base to sides, first screwing down corners then
# going along edges. Be careful that screws go straight into
# plywood walls, without protruding through sides.
# 6.
# Turn the shelter back to upright position.
# 7.
# Cut and staple insulation blueboard to inside of side walls A
# and B.
# 8.
# Attach front and back posts for front and back wall supports.
# Note that the posts are placed flat against the front and back
# walls, at right angles to the corner posts, as shown. The post
# next to the front door should be 5-1/2 inches from the right
# interior wall to leave room for the wind block.
# 9.
# Cut and staple the remaining insulation to the inside of
# front and back walls.
# 10.
# Put the wind block in place and screw it to the front of the
# shelter, then to bottom (do this from outside in).
# 11.
# For extra cat sleeping room, screw 5-in. shelf braces upright
# to the center of wind block and left interior wall near the
# front corner of shelter to support shelf, if desired. Then
# screw 9-in. x 2-ft. 3.5-in. shelf on top of braces.
# 12.
# Place the 2-ft. 7-in. x 3-ft. 3-in. roof on bench and turn
# shelter upside down. Center shelter on the roof with roof
# hanging over on all sides. Screw hinges to the underside of
# the roof and outside the front of the shelter so it will open
# easily and stand up straight on its own.
# 13.
# Turn the shelter back over and attach shingles with roofing
# nails in an offset pattern to seal against weather. After nailing
# shingles bend nail points over to avoid injuring cats.
# BUILD AN INEXPENSIVE CAT SHELTER, page 3 of 4
# FRONT
# BACK
# A
# B
# 11” POST
# 11” POST
# 17” POST
# 17” POST
# Steps 1-6
# FRONT
# BACK
# A
# B
# POST
# POST
# POST
# POST
# I
# N
# S
# U
# L
# A
# T
# I
# O
# N
# I
# N
# S
# U
# L
# A
# T
# I
# O
# N
# Steps 7-8
# FRONT
# BACK
# INSULATION
# WINDBLOCK
# INSULATION
# Steps 9-10
# SHELF
# Step 11
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# 14.
# Place the vinyl floor tiles inside if desired for extra protection.
# 15.
# Paint the shelter (all exposed wood should be painted,
# including bottom, to protect it from rain and/or snow).
# 16.When installing the shelter, make sure to set it on top of
# bricks or other objects to keep it away from ground contact.
# Also take prevailing winds and exposure into account; placing
# shelter front facing south often maximizes warmth.
# Note:
# You may also cover the interior underside of the roof
# with fiberglass or plastic foam insulation, but be sure to cover
# it with plastic or wood. Foam needs to be covered to hold it in
# place, and uncovered fiberglass will harm cats. You can insulate
# the shelter with strong plastic to keep out wind, rain, and cold.
# Leave a small opening for the cats to enter. A flap can be placed
# over the entrance for added protection.
# BUILD AN INEXPENSIVE CAT SHELTER, page 4 of 4
# Shelter design and construction drawings by Bill McFadden and Ken Crawford.
# Shelter illustration by Doug Hall.
# Shelter Interior
# Shelter Exterior
#
# ========================================================================================================================================================================================================www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# BUILD AN INEXPENSIVE CAT SHELTER
# The following instructions are for building an
# insulated cat shelter 2 ft. x 3 ft. x 18in. high.
# You should be able to buy the materials at a local lumberyard.
# An electric saw and screwdriver are highly recommended.
# Caution: If you are not experienced with an electric saw, ask a
# skilled person to cut the wood and paneling.
# Materials Needed
# •
# One 4-ft. x 1/2-in x 8-ft. sheet of exterior grade plywood
# or waferboard
# •
# One 4-ft. x 8-ft. sheet interior paneling or thin plywood
# One package roofing shingles or enough to cover
# 8-sq. ft. roof
# •
# Two 2-in. x 3-in. x 6-ft. untreated lumber
# Linoleum or other floor tiles (to cover 6-sq. ft. floor)
# •
# One quart exterior house paint
# Two medium hinges (“T” or gate hinges)
# •
# Fifty 2-in. flat head wood screws or grippers
# Four to nine bricks for foundation
# •
# Small roofing nails (approximately 15)
# Fiberglass insulation (1 roll, or enough to cover 14-20 sq. ft.)
# Tools Needed
# •
# Hammer
# Saw
# •
# Electric screw
# driver
# •
# Angle brace or
# T-square
# •
# Staple gun
# Measuring tape
# •
# Marking pen
# Things to consider before starting your project
# These will help you determine what you need to buy and
# how much work will be involved, and also provide a few
# helpful hints.
# •
# How many cats do you need to house? This number
# detemines how many shelters to build. Keep in mind that
# not all cats are likely to use the shelter, or at least not all at
# the same time. This shelter should probably house no more
# than five to seven cats at once. You can adjust this plan
# to make a larger shelter, or build more than one shelter
# as needed.
# Caregiving
# Information
# A
# lley Cat Allies recommends that feral cat colonies have proper protection from inclement weather.
# Following are detailed instructions needed to build a feral cat shelter. These building plans are
# recommended for use throughout the United States. For extremely harsh, cold, and wet climates,
# insulation (as described) is advised. Other types of shelters, such as dog igloos, can be used in less
# harsh climates. Go to www.alleycat.org/BuildaShelter for additional shelter ideas.
# Completed shelter
# Caregiving Information
# 317P
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# BUILD AN INEXPENSIVE CAT SHELTER, page 2 of 4
# •
# Be sure to make the shelter small enough for transport in
# your vehicle. The shelter size described here will fit in a
# standard size car trunk with the trunk lid open.
# •
# If you live in a climate that gets very cold, we recommend
# that you use insulation as described in the plans.
# •
# Use only exterior paint to reduce weather exposure,
# preferably dark green or dark brown to match natural
# surroundings.
# •
# Floor should have linoleum or tile square instead of
# carpet to reduce the chance of flea infestation. Carpets and
# towels retain moisture and should not be used.
# Assembly
# 1.
# Cut wood. For easy assembly, cut all wood first, then
# assemble the shelter. Some pieces may need adjustment
# after cutting.
# Cut plywood as shown at right. (This is only enough for
# one shelter.)
# Cut paneling as shown at right. One sheet of paneling
# is enough for two shelters.
# Cut 2-in. x 3-in. x 6-ft. lumber into eight posts and
# two shelf braces as shown at right.
# •
# Use screws, not nails, for better durability.
# Roof should be hinged so bedding can be replaced, and
# for easy access when retrieving kittens who may be in
# the shelter.
# •
# Roof must be slanted to drain off water.
# A wind block should be placed inside the door of the shelter
# to improve warmth. You may also consider a canvas flap to
# go over the door.
# •
# Place wood chips or straw inside for warmth and comfort.
# Blankets, towels, and carpets retain moisture.
# Plywood Cutting Guidelines
# Paneling Cutting Guidelines
# Lumber Cutting Guidelines
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# 2.
# Put side wall A in place on the left of the base and screw
# front wall and left side wall together using one 17-in. corner
# post.
# 3.
# Position side wall B on the right and attach to front wall
# using other 17-in. corner post.
# 4.
# Position back wall and attach to both side walls using two
# 11-in. corner posts.
# Note:
# Corner posts should rest on
# top of the base, as should the front, back, and side walls.
# All posts should be inside of the front, back, and side walls.
# 5.
# Turn walls upside down and place the 3-ft. x 2-ft. base on
# top. Mount base to sides, first screwing down corners then
# going along edges. Be careful that screws go straight into
# plywood walls, without protruding through sides.
# 6.
# Turn the shelter back to upright position.
# 7.
# Cut and staple insulation blueboard to inside of side walls A
# and B.
# 8.
# Attach front and back posts for front and back wall supports.
# Note that the posts are placed flat against the front and back
# walls, at right angles to the corner posts, as shown. The post
# next to the front door should be 5-1/2 inches from the right
# interior wall to leave room for the wind block.
# 9.
# Cut and staple the remaining insulation to the inside of
# front and back walls.
# 10.
# Put the wind block in place and screw it to the front of the
# shelter, then to bottom (do this from outside in).
# 11.
# For extra cat sleeping room, screw 5-in. shelf braces upright
# to the center of wind block and left interior wall near the
# front corner of shelter to support shelf, if desired. Then
# screw 9-in. x 2-ft. 3.5-in. shelf on top of braces.
# 12.
# Place the 2-ft. 7-in. x 3-ft. 3-in. roof on bench and turn
# shelter upside down. Center shelter on the roof with roof
# hanging over on all sides. Screw hinges to the underside of
# the roof and outside the front of the shelter so it will open
# easily and stand up straight on its own.
# 13.
# Turn the shelter back over and attach shingles with roofing
# nails in an offset pattern to seal against weather. After nailing
# shingles bend nail points over to avoid injuring cats.
# BUILD AN INEXPENSIVE CAT SHELTER, page 3 of 4
# FRONT
# BACK
# A
# B
# 11” POST
# 11” POST
# 17” POST
# 17” POST
# Steps 1-6
# FRONT
# BACK
# A
# B
# POST
# POST
# POST
# POST
# I
# N
# S
# U
# L
# A
# T
# I
# O
# N
# I
# N
# S
# U
# L
# A
# T
# I
# O
# N
# Steps 7-8
# FRONT
# BACK
# INSULATION
# WINDBLOCK
# INSULATION
# Steps 9-10
# SHELF
# Step 11
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# 14.
# Place the vinyl floor tiles inside if desired for extra protection.
# 15.
# Paint the shelter (all exposed wood should be painted,
# including bottom, to protect it from rain and/or snow).
# 16.When installing the shelter, make sure to set it on top of
# bricks or other objects to keep it away from ground contact.
# Also take prevailing winds and exposure into account; placing
# shelter front facing south often maximizes warmth.
# Note:
# You may also cover the interior underside of the roof
# with fiberglass or plastic foam insulation, but be sure to cover
# it with plastic or wood. Foam needs to be covered to hold it in
# place, and uncovered fiberglass will harm cats. You can insulate
# the shelter with strong plastic to keep out wind, rain, and cold.
# Leave a small opening for the cats to enter. A flap can be placed
# over the entrance for added protection.
# BUILD AN INEXPENSIVE CAT SHELTER, page 4 of 4
# Shelter design and construction drawings by Bill McFadden and Ken Crawford.
# Shelter illustration by Doug Hall.
# Shelter Interior
# Shelter Exterior
#
# ========================================================================================================================================================================================================

# %%
print(data[0]['documents'][0])
# Out:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# BUILD AN INEXPENSIVE CAT SHELTER
# The following instructions are for building an
# insulated cat shelter 2 ft. x 3 ft. x 18in. high.
# You should be able to buy the materials at a local lumberyard.
# An electric saw and screwdriver are highly recommended.
# Caution: If you are not experienced with an electric saw, ask a
# skilled person to cut the wood and paneling.
# Materials Needed
# •
# One 4-ft. x 1/2-in x 8-ft. sheet of exterior grade plywood
# or waferboard
# •
# One 4-ft. x 8-ft. sheet interior paneling or thin plywood
# One package roofing shingles or enough to cover
# 8-sq. ft. roof
# •
# Two 2-in. x 3-in. x 6-ft. untreated lumber
# Linoleum or other floor tiles (to cover 6-sq. ft. floor)
# •
# One quart exterior house paint
# Two medium hinges (“T” or gate hinges)
# •
# Fifty 2-in. flat head wood screws or grippers
# Four to nine bricks for foundation
# •
# Small roofing nails (approximately 15)
# Fiberglass insulation (1 roll, or enough to cover 14-20 sq. ft.)
# Tools Needed
# •
# Hammer
# Saw
# •
# Electric screw
# driver
# •
# Angle brace or
# T-square
# •
# Staple gun
# Measuring tape
# •
# Marking pen
# Things to consider before starting your project
# These will help you determine what you need to buy and
# how much work will be involved, and also provide a few
# helpful hints.
# •
# How many cats do you need to house? This number
# detemines how many shelters to build. Keep in mind that
# not all cats are likely to use the shelter, or at least not all at
# the same time. This shelter should probably house no more
# than five to seven cats at once. You can adjust this plan
# to make a larger shelter, or build more than one shelter
# as needed.
# Caregiving
# Information
# A
# lley Cat Allies recommends that feral cat colonies have proper protection from inclement weather.
# Following are detailed instructions needed to build a feral cat shelter. These building plans are
# recommended for use throughout the United States. For extremely harsh, cold, and wet climates,
# insulation (as described) is advised. Other types of shelters, such as dog igloos, can be used in less
# harsh climates. Go to www.alleycat.org/BuildaShelter for additional shelter ideas.
# Completed shelter
# Caregiving Information
# 317P
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# BUILD AN INEXPENSIVE CAT SHELTER, page 2 of 4
# •
# Be sure to make the shelter small enough for transport in
# your vehicle. The shelter size described here will fit in a
# standard size car trunk with the trunk lid open.
# •
# If you live in a climate that gets very cold, we recommend
# that you use insulation as described in the plans.
# •
# Use only exterior paint to reduce weather exposure,
# preferably dark green or dark brown to match natural
# surroundings.
# •
# Floor should have linoleum or tile square instead of
# carpet to reduce the chance of flea infestation. Carpets and
# towels retain moisture and should not be used.
# Assembly
# 1.
# Cut wood. For easy assembly, cut all wood first, then
# assemble the shelter. Some pieces may need adjustment
# after cutting.
# Cut plywood as shown at right. (This is only enough for
# one shelter.)
# Cut paneling as shown at right. One sheet of paneling
# is enough for two shelters.
# Cut 2-in. x 3-in. x 6-ft. lumber into eight posts and
# two shelf braces as shown at right.
# •
# Use screws, not nails, for better durability.
# Roof should be hinged so bedding can be replaced, and
# for easy access when retrieving kittens who may be in
# the shelter.
# •
# Roof must be slanted to drain off water.
# A wind block should be placed inside the door of the shelter
# to improve warmth. You may also consider a canvas flap to
# go over the door.
# •
# Place wood chips or straw inside for warmth and comfort.
# Blankets, towels, and carpets retain moisture.
# Plywood Cutting Guidelines
# Paneling Cutting Guidelines
# Lumber Cutting Guidelines
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# 2.
# Put side wall A in place on the left of the base and screw
# front wall and left side wall together using one 17-in. corner
# post.
# 3.
# Position side wall B on the right and attach to front wall
# using other 17-in. corner post.
# 4.
# Position back wall and attach to both side walls using two
# 11-in. corner posts.
# Note:
# Corner posts should rest on
# top of the base, as should the front, back, and side walls.
# All posts should be inside of the front, back, and side walls.
# 5.
# Turn walls upside down and place the 3-ft. x 2-ft. base on
# top. Mount base to sides, first screwing down corners then
# going along edges. Be careful that screws go straight into
# plywood walls, without protruding through sides.
# 6.
# Turn the shelter back to upright position.
# 7.
# Cut and staple insulation blueboard to inside of side walls A
# and B.
# 8.
# Attach front and back posts for front and back wall supports.
# Note that the posts are placed flat against the front and back
# walls, at right angles to the corner posts, as shown. The post
# next to the front door should be 5-1/2 inches from the right
# interior wall to leave room for the wind block.
# 9.
# Cut and staple the remaining insulation to the inside of
# front and back walls.
# 10.
# Put the wind block in place and screw it to the front of the
# shelter, then to bottom (do this from outside in).
# 11.
# For extra cat sleeping room, screw 5-in. shelf braces upright
# to the center of wind block and left interior wall near the
# front corner of shelter to support shelf, if desired. Then
# screw 9-in. x 2-ft. 3.5-in. shelf on top of braces.
# 12.
# Place the 2-ft. 7-in. x 3-ft. 3-in. roof on bench and turn
# shelter upside down. Center shelter on the roof with roof
# hanging over on all sides. Screw hinges to the underside of
# the roof and outside the front of the shelter so it will open
# easily and stand up straight on its own.
# 13.
# Turn the shelter back over and attach shingles with roofing
# nails in an offset pattern to seal against weather. After nailing
# shingles bend nail points over to avoid injuring cats.
# BUILD AN INEXPENSIVE CAT SHELTER, page 3 of 4
# FRONT
# BACK
# A
# B
# 11” POST
# 11” POST
# 17” POST
# 17” POST
# Steps 1-6
# FRONT
# BACK
# A
# B
# POST
# POST
# POST
# POST
# I
# N
# S
# U
# L
# A
# T
# I
# O
# N
# I
# N
# S
# U
# L
# A
# T
# I
# O
# N
# Steps 7-8
# FRONT
# BACK
# INSULATION
# WINDBLOCK
# INSULATION
# Steps 9-10
# SHELF
# Step 11
# Fact Sheet:
# www.alleycat.org • 7920 Norfolk Avenue, Suite 600 • Bethesda, MD 20814-2525 • ©2017
# 14.
# Place the vinyl floor tiles inside if desired for extra protection.
# 15.
# Paint the shelter (all exposed wood should be painted,
# including bottom, to protect it from rain and/or snow).
# 16.When installing the shelter, make sure to set it on top of
# bricks or other objects to keep it away from ground contact.
# Also take prevailing winds and exposure into account; placing
# shelter front facing south often maximizes warmth.
# Note:
# You may also cover the interior underside of the roof
# with fiberglass or plastic foam insulation, but be sure to cover
# it with plastic or wood. Foam needs to be covered to hold it in
# place, and uncovered fiberglass will harm cats. You can insulate
# the shelter with strong plastic to keep out wind, rain, and cold.
# Leave a small opening for the cats to enter. A flap can be placed
# over the entrance for added protection.
# BUILD AN INEXPENSIVE CAT SHELTER, page 4 of 4
# Shelter design and construction drawings by Bill McFadden and Ken Crawford.
# Shelter illustration by Doug Hall.
# Shelter Interior
# Shelter Exterior

# %%
from instructlab.sdg.utils.taxonomy import leaf_node_to_samples


chunked_samples = leaf_node_to_samples(
  leaf_node=data,
  taxonomy_path=Path('./cat-shelter-example'),
  server_ctx_size=4096,
  chunk_word_count=1024,
  document_output_dir=Path('./output'),
  model_name='gpt2'
)
# Out:
# Failed to load tokenizer as no valid model was not found at gpt2. Please provide a path to a valid model format. For help on downloading models, run `ilab model download --help`.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 4
#       1 from instructlab.sdg.utils.taxonomy import leaf_node_to_samples
# ----> 4 chunked_samples = leaf_node_to_samples(
#       5   leaf_node=data,
#       6   taxonomy_path=Path('./cat-shelter-example'),
#       7   server_ctx_size=4096,
#       8   chunk_word_count=1024,
#       9   document_output_dir=Path('./output'),
#      10   model_name='gpt2'
#      11 )
#
# File ~/Programming/labrador/sdg/src/instructlab/sdg/utils/taxonomy.py:463, in leaf_node_to_samples(leaf_node, taxonomy_path, server_ctx_size, chunk_word_count, document_output_dir, model_name, docling_model_path)
#     461     return []
#     462 if leaf_node[0].get("documents"):
# --> 463     return _knowledge_leaf_node_to_samples(
#     464         leaf_node,
#     465         taxonomy_path,
#     466         server_ctx_size,
#     467         chunk_word_count,
#     468         document_output_dir,
#     469         model_name,
#     470         docling_model_path,
#     471     )
#     472 return _skill_leaf_node_to_samples(leaf_node)
#
# File ~/Programming/labrador/sdg/src/instructlab/sdg/utils/taxonomy.py:421, in _knowledge_leaf_node_to_samples(leaf_node, taxonomy_path, server_ctx_size, chunk_word_count, document_output_dir, model_name, docling_model_path)
#     412 def _knowledge_leaf_node_to_samples(
#     413     leaf_node,
#     414     taxonomy_path,
#    (...)
#     419     docling_model_path=None,
#     420 ):
# --> 421     chunker = DocumentChunker(
#     422         leaf_node=leaf_node,
#     423         taxonomy_path=taxonomy_path,
#     424         output_dir=document_output_dir,
#     425         server_ctx_size=server_ctx_size,
#     426         chunk_word_count=chunk_word_count,
#     427         tokenizer_model_name=model_name,
#     428         docling_model_path=docling_model_path,
#     429     )
#     430     chunks = chunker.chunk_documents()
#     432     samples = map_chunks_to_icls(chunks, leaf_node)
#
# File ~/Programming/labrador/sdg/src/instructlab/sdg/utils/chunkers.py:146, in DocumentChunker.__new__(cls, leaf_node, taxonomy_path, output_dir, server_ctx_size, chunk_word_count, tokenizer_model_name, docling_model_path)
#     144 if FileTypes.PDF in doc_dict:
#     145     doc_paths = [p for _, p in doc_dict[FileTypes.PDF]]
# --> 146     return ContextAwareChunker(
#     147         doc_paths,
#     148         filepaths,
#     149         output_dir,
#     150         chunk_word_count,
#     151         tokenizer_model_name,
#     152         docling_model_path=docling_model_path,
#     153     )
#
# File ~/Programming/labrador/sdg/src/instructlab/sdg/utils/chunkers.py:233, in ContextAwareChunker.__init__(self, document_paths, filepaths, output_dir, chunk_word_count, tokenizer_model_name, docling_model_path)
#     231 self.output_dir = self._path_validator(output_dir)
#     232 self.chunk_word_count = chunk_word_count
# --> 233 self.tokenizer = self.create_tokenizer(tokenizer_model_name)
#     234 self.docling_model_path = docling_model_path
#
# File ~/Programming/labrador/sdg/src/instructlab/sdg/utils/chunkers.py:400, in ContextAwareChunker.create_tokenizer(model_name)
#     396 except (OSError, ValueError) as e:
#     397     logger.error(
#     398         f"Failed to load tokenizer as no valid model was not found at {model_path}. {error_info_message}"
#     399     )
# --> 400     raise e
#
# File ~/Programming/labrador/sdg/src/instructlab/sdg/utils/chunkers.py:391, in ContextAwareChunker.create_tokenizer(model_name)
#     389 else:
#     390     error_info_message = "Please provide a path to a valid model format. For help on downloading models, run `ilab model download --help`."
# --> 391     raise ValueError()
#     393 logger.info(f"Successfully loaded tokenizer from: {model_path}")
#     394 return tokenizer
#
# ValueError:
